# %%
#
# this is experiment 1
import requests
import urllib.request
import time
from bs4 import BeautifulSoup
import csv

#url = "https://capetown-airport.co.za/flights/arrivals/"
direction=0
timespan=2
url = "https://www.flightstats.com/go/weblet?guid=49e3481552e7c4c9:-5b147615:12ec353094a:-205f&weblet=status&action=AirportFlightStatus&airportCode=CPT&airportQueryType={}&airportQueryTimePeriod={}".format(direction,timespan)
print("url="+url)
#                        <input type="hidden" name="language" value="English"/>
#                        <input type="hidden" name="startAction" value="AirportFlightStatus"/>
#                        <input type="hidden" name="imageColor" value="orange"/>


post_data = {
                "language":"English",
                "startAction":"AirportFlightStatus",
                "imageColor":"orange",
                "airportQueryTimePeriod":"0",
                "airportQueryType":"1"
            }

post_headers = {"content-type","application/x-www-form-urlencoded"}
post_headers = {}

#print("POST request...data=",post_data)
#response = requests.post(url=url,data=post_data, headers=post_headers)
response = requests.get(url)

print(response)
#print(response.text)

soup = BeautifulSoup(response.text, "html.parser")

tables = soup.findAll("table")
num_tables = len(tables)
#for tabndx in range(0,num_tables):
#    table = tables[tabndx]
#    print("TABLE#",tabndx,"...",table)

#
# this is the flight data result...found by inspection
table = tables[4]

all_rows = []
rows = table.findAll("tr")
for r in rows:
    newrow = []
    cols = r.findAll("td")
    for c in cols:
        #
        # fix the text in the string
        cellval = c.get_text().strip()
        cellval = cellval.replace("\n^","")
        newrow.append(cellval)
    all_rows.append(newrow)
    
for row in all_rows:
    print("row=",row)
# Out:
# url=https://www.flightstats.com/go/weblet?guid=49e3481552e7c4c9:-5b147615:12ec353094a:-205f&weblet=status&action=AirportFlightStatus&airportCode=CPT&airportQueryType=0&airportQueryTimePeriod=2
# <Response [200]>
# row= ['Flight', 'Carrier', 'Destination', 'Departure', 'Status']
# row= ['FA* 128', 'Safair', '(JNB) Johannesburg', '5:50 AM', 'En Route']
# row= ['FA* 104', 'Safair', '(JNB) Johannesburg', '5:50 AM', 'En Route']
# row= ['SW 700', 'Air Namibia', '(WDH) Windhoek', '5:55 AM', 'En Route']
# row= ['KQ 3342', 'Kenya Airways', '(WDH) Windhoek', '5:55 AM', 'En Route']

# %%
#
# function to scrape direction and timespan
#
import requests
import urllib.request
import time
from bs4 import BeautifulSoup
import csv
import sys

#
# airport - IATA 3 letter airport code
# direction - 0 = arrivals, 1 = departures
# timespan - index of 3 hour blocks: 1 = 00:00-03:00, 2=03:00-06:00 ... , 8=21:00-00:00
#
def getFlights(airport,direction,timespan):
    #
    # I think this is the embedded API key that capetown-airport.co.za uses for flightstats???
    urlbase = "https://www.flightstats.com/go/weblet?guid=49e3481552e7c4c9:-5b147615:12ec353094a:-205f"
    urlbase = "https://www.flightstats.com/go/weblet"
    urlparams = {
        "guid":"49e3481552e7c4c9:-5b147615:12ec353094a:-205f",
        "weblet":"status",
        "action":"AirportFlightStatus",
        "airportCode":airport,
        "airportQueryType":direction,
        "airportQueryTimePeriod":timespan
    }
    
    print("send query...",airport,direction,timespan)
    rsp = requests.get(urlbase,params=urlparams)
    print("url was...",rsp.request.url)
    return rsp

def parseFlightRsp(rsp,dlabel=0):
    soup = BeautifulSoup(rsp.text, "html.parser")
    tables = soup.findAll("table")
    num_tables = len(tables)
    # this is the flight data result...found by inspection
    table = tables[4]

    all_rows = []
    rows = table.findAll("tr")
    for r in rows:
        newrow = [dlabel]
        cols = r.findAll("td")
        for c in cols:
            #
            # fix the text in the string
            cellval = c.get_text().strip()
            cellval = cellval.replace("\n","")
            newrow.append(cellval)
        all_rows.append(newrow)
    return all_rows


all_rows = []
directions = {0:"Dep",1:"Arr"}
timeblocks = [1,2,3,4,5,6,7,8]

for t in timeblocks:
    for d,dl in directions.items():
        print(d,dl)
        rsp = getFlights("YVR",d,t)
        rows = parseFlightRsp(rsp,dlabel=dl)
        all_rows = all_rows + rows
        print("found",len(rows),"records")
        
csvout = csv.writer(sys.stdout)
csvout.writerows(all_rows)
# Out:
# 0 Dep
# send query... YVR 0 1
# url was... https://www.flightstats.com/go/weblet?guid=49e3481552e7c4c9%3A-5b147615%3A12ec353094a%3A-205f&weblet=status&action=AirportFlightStatus&airportCode=YVR&airportQueryType=0&airportQueryTimePeriod=1
# found 13 records
# 1 Arr
# send query... YVR 1 1
# url was... https://www.flightstats.com/go/weblet?guid=49e3481552e7c4c9%3A-5b147615%3A12ec353094a%3A-205f&weblet=status&action=AirportFlightStatus&airportCode=YVR&airportQueryType=1&airportQueryTimePeriod=1
# found 20 records
# 0 Dep
# send query... YVR 0 2
# url was... https://www.flightstats.com/go/weblet?guid=49e3481552e7c4c9%3A-5b147615%3A12ec353094a%3A-205f&weblet=status&action=AirportFlightStatus&airportCode=YVR&airportQueryType=0&airportQueryTimePeriod=2
# found 1 records
# 1 Arr
# send query... YVR 1 2
# url was... https://www.flightstats.com/go/weblet?guid=49e3481552e7c4c9%3A-5b147615%3A12ec353094a%3A-205f&weblet=status&action=AirportFlightStatus&airportCode=YVR&airportQueryType=1&airportQueryTimePeriod=2
# found 3 records
# 0 Dep
# send query... YVR 0 3
# url was... https://www.flightstats.com/go/weblet?guid=49e3481552e7c4c9%3A-5b147615%3A12ec353094a%3A-205f&weblet=status&action=AirportFlightStatus&airportCode=YVR&airportQueryType=0&airportQueryTimePeriod=3
# found 110 records
# 1 Arr
# send query... YVR 1 3
# url was... https://www.flightstats.com/go/weblet?guid=49e3481552e7c4c9%3A-5b147615%3A12ec353094a%3A-205f&weblet=status&action=AirportFlightStatus&airportCode=YVR&airportQueryType=1&airportQueryTimePeriod=3
# found 97 records
# 0 Dep
# send query... YVR 0 4
# url was... https://www.flightstats.com/go/weblet?guid=49e3481552e7c4c9%3A-5b147615%3A12ec353094a%3A-205f&weblet=status&action=AirportFlightStatus&airportCode=YVR&airportQueryType=0&airportQueryTimePeriod=4
# found 109 records
# 1 Arr
# send query... YVR 1 4
# url was... https://www.flightstats.com/go/weblet?guid=49e3481552e7c4c9%3A-5b147615%3A12ec353094a%3A-205f&weblet=status&action=AirportFlightStatus&airportCode=YVR&airportQueryType=1&airportQueryTimePeriod=4
# found 221 records
# 0 Dep
# send query... YVR 0 5
# url was... https://www.flightstats.com/go/weblet?guid=49e3481552e7c4c9%3A-5b147615%3A12ec353094a%3A-205f&weblet=status&action=AirportFlightStatus&airportCode=YVR&airportQueryType=0&airportQueryTimePeriod=5
# found 219 records
# 1 Arr
# send query... YVR 1 5
# url was... https://www.flightstats.com/go/weblet?guid=49e3481552e7c4c9%3A-5b147615%3A12ec353094a%3A-205f&weblet=status&action=AirportFlightStatus&airportCode=YVR&airportQueryType=1&airportQueryTimePeriod=5
# found 182 records
# 0 Dep
# send query... YVR 0 6
# url was... https://www.flightstats.com/go/weblet?guid=49e3481552e7c4c9%3A-5b147615%3A12ec353094a%3A-205f&weblet=status&action=AirportFlightStatus&airportCode=YVR&airportQueryType=0&airportQueryTimePeriod=6
# found 132 records
# 1 Arr
# send query... YVR 1 6
# url was... https://www.flightstats.com/go/weblet?guid=49e3481552e7c4c9%3A-5b147615%3A12ec353094a%3A-205f&weblet=status&action=AirportFlightStatus&airportCode=YVR&airportQueryType=1&airportQueryTimePeriod=6
# found 140 records
# 0 Dep
# send query... YVR 0 7
# url was... https://www.flightstats.com/go/weblet?guid=49e3481552e7c4c9%3A-5b147615%3A12ec353094a%3A-205f&weblet=status&action=AirportFlightStatus&airportCode=YVR&airportQueryType=0&airportQueryTimePeriod=7
# found 127 records
# 1 Arr
# send query... YVR 1 7
# url was... https://www.flightstats.com/go/weblet?guid=49e3481552e7c4c9%3A-5b147615%3A12ec353094a%3A-205f&weblet=status&action=AirportFlightStatus&airportCode=YVR&airportQueryType=1&airportQueryTimePeriod=7
# found 135 records
# 0 Dep
# send query... YVR 0 8
# url was... https://www.flightstats.com/go/weblet?guid=49e3481552e7c4c9%3A-5b147615%3A12ec353094a%3A-205f&weblet=status&action=AirportFlightStatus&airportCode=YVR&airportQueryType=0&airportQueryTimePeriod=8
# found 71 records
# 1 Arr
# send query... YVR 1 8
# url was... https://www.flightstats.com/go/weblet?guid=49e3481552e7c4c9%3A-5b147615%3A12ec353094a%3A-205f&weblet=status&action=AirportFlightStatus&airportCode=YVR&airportQueryType=1&airportQueryTimePeriod=8
# found 100 records
# Dep,Flight,Carrier,Destination,Departure,Status
# Dep,AC 44,Air Canada,(DEL) Delhi,1:15 AM,En Route
# Dep,UA 8095^,United Airlines,(DEL) Delhi,1:15 AM,En Route
# Dep,BR 9,EVA Air,(TPE) Taipei,2:00 AM,En Route
# Dep,SQ 5809^,Singapore Airlines,(TPE) Taipei,2:00 AM,En Route
# Dep,TG 6345^,Thai Airways International,(TPE) Taipei,2:00 AM,En Route
# Dep,CI 31,China Airlines,(TPE) Taipei,2:00 AM,En Route
# Dep,VN 2035^,Vietnam Airlines,(TPE) Taipei,2:00 AM,En Route
# Dep,CX 865,Cathay Pacific,(HKG) Hong Kong,2:20 AM,En Route
# Dep,MU 598,China Eastern Airlines,(PVG) Shanghai,2:30 AM,En Route
# Dep,EY 1003^,Etihad Airways,(PVG) Shanghai,2:30 AM,En Route
# Dep,CA 998,Air China,(PEK) Beijing,2:30 AM,En Route
# Dep,AC 6603^,Air Canada,(PEK) Beijing,2:30 AM,En Route
# Arr,Flight,Carrier,Origin,Arrival,Status
# Arr,WS 725,WestJet,(YYZ) Toronto,12:18 AM,Landed
# Arr,AF 3748^,Air France,(YYZ) Toronto,12:18 AM,Landed
# Arr,CI 9313^,China Airlines,(YYZ) Toronto,12:18 AM,Landed
# Arr,CX 7047^,Cathay Pacific,(YYZ) Toronto,12:18 AM,Landed
# Arr,DL 7131^,Delta Air Lines,(YYZ) Toronto,12:18 AM,Landed
# Arr,HU 8733^,Hainan Airlines,(YYZ) Toronto,12:18 AM,Landed
# Arr,MU 8004^,China Eastern Airlines,(YYZ) Toronto,12:18 AM,Landed
# Arr,AS 2508,Alaska Airlines,(SEA) Seattle,12:20 AM,Landed
# Arr,AA 7460^,American Airlines,(SEA) Seattle,12:20 AM,Landed
# Arr,KE 6165^,Korean Air,(SEA) Seattle,12:20 AM,Landed
# Arr,AC 129,Air Canada,(YYZ) Toronto,12:50 AM,Landed
# Arr,CA 7470^,Air China,(YYZ) Toronto,12:50 AM,Landed
# Arr,EI 8583^,Aer Lingus,(YYZ) Toronto,12:50 AM,Landed
# Arr,LH 6638^,Lufthansa,(YYZ) Toronto,12:50 AM,Landed
# Arr,LO 4137^,LOT - Polish Airlines,(YYZ) Toronto,12:50 AM,Landed
# Arr,OS 8344^,Austrian,(YYZ) Toronto,12:50 AM,Landed
# Arr,CX 865,Cathay Pacific,(JFK) New York,12:50 AM,Landed
# Arr,AA 1365,American Airlines,(DFW) Dallas,12:53 AM,Landed
# Arr,BA 1911^,British Airways,(DFW) Dallas,12:53 AM,Landed
# Dep,Flight,Carrier,Destination,Departure,Status
# Arr,Flight,Carrier,Origin,Arrival,Status
# Arr,AM 694,Aeromexico,(MEX) Mexico City,5:15 AM,Landed
# Arr,WS 6111^,WestJet,(MEX) Mexico City,5:15 AM,Landed
# Dep,Flight,Carrier,Destination,Departure,Status
# Dep,AC 560,Air Canada,(SFO) San Francisco,6:10 AM,Landed
# Dep,NZ 4823^,Air New Zealand,(SFO) San Francisco,6:10 AM,Landed
# Dep,DL 2317,Delta Air Lines,(SEA) Seattle,6:14 AM,Landed
# Dep,WS 8318^,WestJet,(SEA) Seattle,6:14 AM,Landed
# Dep,UA 545,United Airlines,(DEN) Denver,6:15 AM,Landed
# Dep,AC 4592^,Air Canada,(DEN) Denver,6:15 AM,Landed
# Dep,DL 2555,Delta Air Lines,(MSP) Minneapolis,6:20 AM,Landed
# Dep,AF 3455^,Air France,(MSP) Minneapolis,6:20 AM,Landed
# Dep,KE 3838^,Korean Air,(MSP) Minneapolis,6:20 AM,Landed
# Dep,VS 1540^,Virgin Atlantic,(MSP) Minneapolis,6:20 AM,Landed
# Dep,WS 6386^,WestJet,(MSP) Minneapolis,6:20 AM,Landed
# Dep,AC 550,Air Canada,(LAX) Los Angeles,6:30 AM,Landed
# Dep,NZ 4601^,Air New Zealand,(LAX) Los Angeles,6:30 AM,Landed
# Dep,UA 8578^,United Airlines,(LAX) Los Angeles,6:30 AM,Landed
# Dep,AM 695,Aeromexico,(MEX) Mexico City,6:40 AM,En Route
# Dep,WS 6110^,WestJet,(MEX) Mexico City,6:40 AM,En Route
# Dep,AC 8350,Air Canada,(YYF) Penticton,6:45 AM,Landed
# Dep,AA 6072,American Airlines,(LAX) Los Angeles,6:50 AM,Landed
# Dep,AS 6302^,Alaska Airlines,(LAX) Los Angeles,6:50 AM,Landed
# Dep,FJ 5206^,Fiji Airways,(LAX) Los Angeles,6:50 AM,Landed
# Dep,TN 1309^,Air Tahiti Nui,(LAX) Los Angeles,6:50 AM,Landed
# Dep,AA 392,American Airlines,(DFW) Dallas,7:00 AM,En Route
# Dep,BA 4351^,British Airways,(DFW) Dallas,7:00 AM,En Route
# Dep,DL 5766,Delta Air Lines,(SLC) Salt Lake City,7:00 AM,Landed
# Dep,AF 2109^,Air France,(SLC) Salt Lake City,7:00 AM,Landed
# Dep,AM 3591^,Aeromexico,(SLC) Salt Lake City,7:00 AM,Landed
# Dep,KL 7961^,KLM,(SLC) Salt Lake City,7:00 AM,Landed
# Dep,VS 3709^,Virgin Atlantic,(SLC) Salt Lake City,7:00 AM,Landed
# Dep,WS 6408^,WestJet,(SLC) Salt Lake City,7:00 AM,Landed
# Dep,AC 232,Air Canada,(YEG) Edmonton,7:00 AM,Landed
# Dep,NZ 4836^,Air New Zealand,(YEG) Edmonton,7:00 AM,Landed
# Dep,SWG 9489,Sunwing,(YEG) Edmonton,7:00 AM,Landed
#                                         Delayed"ded
# Dep,UA 664,United Airlines,(ORD) Chicago,7:00 AM,En Route
# Dep,AC 5083^,Air Canada,(ORD) Chicago,7:00 AM,En Route
# Dep,EI 6447^,Aer Lingus,(ORD) Chicago,7:00 AM,En Route
# Dep,AC 8246,Air Canada,(YCG) Castlegar,7:15 AM,Landed
# Dep,AC 8201,Air Canada,(YXS) Prince George,7:20 AM,Landed
# Dep,AC 312,Air Canada,(YUL) Montreal,7:25 AM,En Route
# Dep,LH 6529^,Lufthansa,(YUL) Montreal,7:25 AM,En Route
# Dep,LX 4651^,SWISS,(YUL) Montreal,7:25 AM,En Route
# Dep,1I 214,NetJets Aviation,(ZMT) Masset,7:30 AM,Diverted
# Dep,4N 7081,Air North,(ZMT) Masset,7:45 AM,Landed
# Dep,WS 3316,WestJet,(YLW) Kelowna,7:50 AM,Landed
# Dep,AM 7260^,Aeromexico,(YLW) Kelowna,7:50 AM,Landed
# Dep,AC 8887,Air Canada,(YXY) Whitehorse,7:50 AM,En Route
# Dep,AS 2269,Alaska Airlines,(SEA) Seattle,7:50 AM,Landed
# Dep,AA 7597^,American Airlines,(SEA) Seattle,7:50 AM,Landed
# Dep,KE 6164^,Korean Air,(SEA) Seattle,7:50 AM,Landed
# Dep,UA 5947,United Airlines,(LAX) Los Angeles,7:55 AM,En Route
# Dep,AC 4490^,Air Canada,(LAX) Los Angeles,7:55 AM,En Route
# Dep,NZ 9996^,Air New Zealand,(LAX) Los Angeles,7:55 AM,En Route
# Dep,AC 204,Air Canada,(YYC) Calgary,8:00 AM,Landed
# Dep,AC 8690,Air Canada,(SAN) San Diego,8:00 AM,En Route
# Dep,AC 8398,Air Canada,(YLW) Kelowna,8:00 AM,Landed
# Dep,NZ 4580^,Air New Zealand,(YLW) Kelowna,8:00 AM,Landed
#                                         Delayed"Route
#                                         Delayed"oute
#                                         Delayed"n Route
#                                         Delayed" Route
#                                         Delayed"Route
#                                         Delayed"AM,"En Route
# Dep,WS 702,WestJet,(YYZ) Toronto,8:00 AM,En Route
# Dep,DL 7105^,Delta Air Lines,(YYZ) Toronto,8:00 AM,En Route
# Dep,HU 8736^,Hainan Airlines,(YYZ) Toronto,8:00 AM,En Route
# Dep,WS 160,WestJet,(YEG) Edmonton,8:00 AM,Landed
# Dep,AM 7352^,Aeromexico,(YEG) Edmonton,8:00 AM,Landed
# Dep,8P 201,Pacific Coastal Airlines,(YPW) Powell River,8:00 AM,Landed
# Dep,AC 290,Air Canada,(YWG) Winnipeg,8:05 AM,En Route
# Dep,WS 3279,WestJet,(YYJ) Victoria,8:05 AM,Landed
# Dep,AM 7365^,Aeromexico,(YYJ) Victoria,8:05 AM,Landed
# Dep,WS 3277,WestJet,(YXS) Prince George,8:10 AM,Landed
# Dep,AM 7292^,Aeromexico,(YXS) Prince George,8:10 AM,Landed
# Dep,AA 1465,American Airlines,(PHX) Phoenix,8:15 AM,En Route
# Dep,9M 581,Central Mountain Air,(YBL) Campbell River,8:20 AM,Landed
# Dep,AC 6581^,Air Canada,(YBL) Campbell River,8:20 AM,Landed
# Dep,AC 8089,Air Canada,(SEA) Seattle,8:25 AM,Landed
# Dep,NZ 4585^,Air New Zealand,(SEA) Seattle,8:25 AM,Landed
# Dep,UA 8241^,United Airlines,(SEA) Seattle,8:25 AM,Landed
#                                         Delayed"n Route
# Dep,AC 970,Air Canada,(PVR) Puerto Vallarta,8:25 AM,En Route
# Dep,TS 4430,Air Transat,(PVR) Puerto Vallarta,8:30 AM,En Route
# Dep,WS 1696,WestJet,(LAX) Los Angeles,8:30 AM,En Route
# Dep,AM 7391^,Aeromexico,(LAX) Los Angeles,8:30 AM,En Route
# Dep,DL 7047^,Delta Air Lines,(LAX) Los Angeles,8:30 AM,En Route
# Dep,EK 4664^,Emirates,(LAX) Los Angeles,8:30 AM,En Route
# Dep,LA 5178^,LATAM Airlines,(LAX) Los Angeles,8:30 AM,En Route
# Dep,QF 3352^,Qantas,(LAX) Los Angeles,8:30 AM,En Route
# Dep,8P 843,Pacific Coastal Airlines,(YZT) Port Hardy,8:30 AM,En Route
# Dep,WS 2056,WestJet,(CUN) Cancun,8:35 AM,En Route
# Dep,WS 2060,WestJet,(SJD) San Jose Cabo,8:35 AM,En Route
# Dep,WS 3105,WestJet,(YXT) Terrace,8:45 AM,En Route
# Dep,AM 7381^,Aeromexico,(YXT) Terrace,8:45 AM,En Route
# Dep,CI 9354^,China Airlines,(YXT) Terrace,8:45 AM,En Route
# Dep,KL 9570^,KLM,(YXT) Terrace,8:45 AM,En Route
# Dep,WS 3202,WestJet,(YXJ) Fort St. John,8:45 AM,En Route
# Dep,AM 7373^,Aeromexico,(YXJ) Fort St. John,8:45 AM,En Route
# Dep,KL 9626^,KLM,(YXJ) Fort St. John,8:45 AM,En Route
# Dep,AC 548,Air Canada,(EWR) Newark,8:45 AM,En Route
# Dep,AC 8840,Air Canada,(SFO) San Francisco,8:45 AM,En Route
# Dep,NZ 4611^,Air New Zealand,(SFO) San Francisco,8:45 AM,En Route
# Dep,UA 8255^,United Airlines,(SFO) San Francisco,8:45 AM,En Route
# Dep,AC 8736,Air Canada,(YXE) Saskatoon,8:50 AM,En Route
# Dep,CA 7515^,Air China,(YXE) Saskatoon,8:50 AM,En Route
# Dep,AC 8278,Air Canada,(YPR) Prince Rupert,8:50 AM,En Route
# Dep,AC 8236,Air Canada,(YXT) Terrace,8:50 AM,En Route
# Dep,AC 8303,Air Canada,(YQQ) Comox,8:50 AM,Landed
# Dep,AC 8626,Air Canada,(DFW) Dallas,8:55 AM,En Route
# Dep,AC 8215,Air Canada,(YXC) Cranbrook,8:55 AM,En Route
# Arr,Flight,Carrier,Origin,Arrival,Status
# Arr,FX 142,FedEx,(MEM) Memphis,6:14 AM,Landed
# Arr,AC 8256,Air Canada,(YCD) Nanaimo,6:15 AM,Landed
# Arr,W8 551,Cargojet,(YYC) Calgary,6:35 AM,Landed
# Arr,AC 2410,Air Canada,(HNL) Honolulu,6:35 AM,Landed
# Arr,AC 2010,Air Canada,(HNL) Honolulu,6:35 AM,Scheduled
# Arr,AC 8306,Air Canada,(YQQ) Comox,6:35 AM,Landed
# Arr,W8 555,Cargojet,(YEG) Edmonton,6:35 AM,Landed
#                                         Delayed"d
#                                         Delayed"Landed
#                                         Delayed"AM,"Landed
#                                         Delayed"peg,6:59 AM,"Landed
#                                         Delayed":59 AM,"Landed
#                                         Delayed"
#                                         Delayed"Landed
#                                         Delayed"eg,6:59 AM,"Landed
#                                         Delayed"ed
# Arr,WS 3345,WestJet,(YLW) Kelowna,7:00 AM,Landed
# Arr,LA 5208^,LATAM Airlines,(YLW) Kelowna,7:00 AM,Landed
# Arr,WS 3114,WestJet,(YYJ) Victoria,7:02 AM,Landed
# Arr,HX 3643^,Hong Kong Airlines,(YYJ) Victoria,7:02 AM,Landed
# Arr,AC 235,Air Canada,(YEG) Edmonton,7:03 AM,Landed
# Arr,5X 490,UPS,(BFI) Seattle,7:07 AM,Scheduled
# Arr,5X 6490,UPS,(SDF) Louisville,7:08 AM,Landed
# Arr,WS 1865,WestJet,(HNL) Honolulu,7:11 AM,Landed
# Arr,AF 3745^,Air France,(HNL) Honolulu,7:11 AM,Landed
# Arr,DL 7125^,Delta Air Lines,(HNL) Honolulu,7:11 AM,Landed
# Arr,JL 5819^,JAL,(HNL) Honolulu,7:11 AM,Landed
# Arr,KE 6572^,Korean Air,(HNL) Honolulu,7:11 AM,Landed
# Arr,KL 9673^,KLM,(HNL) Honolulu,7:11 AM,Landed
# Arr,QF 3381^,Qantas,(HNL) Honolulu,7:11 AM,Landed
# Arr,AC 8571,Air Canada,(YQR) Regina,7:15 AM,Landed
# Arr,CA 7518^,Air China,(YQR) Regina,7:15 AM,Landed
# Arr,NH 6843^,ANA,(YQR) Regina,7:15 AM,Landed
# Arr,AC 36,Air Canada,(BNE) Brisbane,7:15 AM,Landed
# Arr,WS 1853,WestJet,(OGG) Kahului,7:17 AM,Landed
# Arr,AF 3746^,Air France,(OGG) Kahului,7:17 AM,Landed
# Arr,KL 9671^,KLM,(OGG) Kahului,7:17 AM,Landed
# Arr,AC 8202,Air Canada,(YXS) Prince George,7:17 AM,Landed
# Arr,WS 3290,WestJet,(YXS) Prince George,7:19 AM,Landed
# Arr,CZ 7550^,China Southern Airlines,(YXS) Prince George,7:19 AM,Landed
# Arr,HX 3641^,Hong Kong Airlines,(YXS) Prince George,7:19 AM,Landed
# Arr,AC 8834,Air Canada,(YZF) Yellowknife,7:21 AM,Landed
# Arr,8P 100,Pacific Coastal Airlines,(YYJ) Victoria,7:25 AM,Landed
# Arr,AC 8176,Air Canada,(YXJ) Fort St. John,7:26 AM,Landed
# Arr,AC 8050,Air Canada,(YYJ) Victoria,7:29 AM,Landed
#                                         Delayed"d
#                                         Delayed"M,"Landed
# Arr,WS 3340,WestJet,(YCD) Nanaimo,7:32 AM,Landed
# Arr,AC 8237,Air Canada,(YXT) Terrace,7:33 AM,Landed
# Arr,LH 6562^,Lufthansa,(YXT) Terrace,7:33 AM,Landed
# Arr,WS 171,WestJet,(YEG) Edmonton,7:33 AM,Landed
# Arr,AF 3734^,Air France,(YEG) Edmonton,7:33 AM,Landed
# Arr,CX 7009^,Cathay Pacific,(YEG) Edmonton,7:33 AM,Landed
# Arr,CZ 7503^,China Southern Airlines,(YEG) Edmonton,7:33 AM,Landed
# Arr,HX 3611^,Hong Kong Airlines,(YEG) Edmonton,7:33 AM,Landed
# Arr,MU 8014^,China Eastern Airlines,(YEG) Edmonton,7:33 AM,Landed
# Arr,AC 8258,Air Canada,(YCD) Nanaimo,7:50 AM,Landed
# Arr,8P 740,Pacific Coastal Airlines,(YQQ) Comox,7:50 AM,Landed
# Arr,WS 115,WestJet,(YYC) Calgary,7:56 AM,Landed
# Arr,CX 7027^,Cathay Pacific,(YYC) Calgary,7:56 AM,Landed
# Arr,DL 7102^,Delta Air Lines,(YYC) Calgary,7:56 AM,Landed
# Arr,AC 295,Air Canada,(YWG) Winnipeg,7:59 AM,Landed
# Arr,AC 8413,Air Canada,(YLW) Kelowna,8:00 AM,Landed
# Arr,CA 7508^,Air China,(YLW) Kelowna,8:00 AM,Landed
# Arr,NZ 4525^,Air New Zealand,(YLW) Kelowna,8:00 AM,Landed
# Arr,8P 750,Pacific Coastal Airlines,(YBL) Campbell River,8:00 AM,Landed
# Arr,WS 3309,WestJet,(YLW) Kelowna,8:00 AM,Landed
# Arr,CX 7013^,Cathay Pacific,(YLW) Kelowna,8:00 AM,Landed
# Arr,DL 7083^,Delta Air Lines,(YLW) Kelowna,8:00 AM,Landed
# Arr,AC 187,Air Canada,(YYZ) Toronto,8:04 AM,Landed
#                                         Delayed"anded
#                                         Delayed"anded
#                                         Delayed" AM,"Landed
# Arr,CX 856,Cathay Pacific,(HKG) Hong Kong,8:10 AM,Landed
# Arr,AC 237,Air Canada,(YEG) Edmonton,8:13 AM,Landed
# Arr,NZ 4503^,Air New Zealand,(YEG) Edmonton,8:13 AM,Landed
# Arr,AC 8120,Air Canada,(PDX) Portland,8:13 AM,Landed
# Arr,UA 8216^,United Airlines,(PDX) Portland,8:13 AM,Landed
# Arr,AC 8892,Air Canada,(YXY) Whitehorse,8:15 AM,Landed
# Arr,LH 6657^,Lufthansa,(YXY) Whitehorse,8:15 AM,Landed
#                                         Delayed"M,"Landed
#                                         Delayed"ed
# Arr,AC 8561,Air Canada,(YYD) Smithers,8:22 AM,Landed
# Arr,AC 205,Air Canada,(YYC) Calgary,8:26 AM,Landed
# Arr,OZ 6109^,Asiana Airlines,(YYC) Calgary,8:26 AM,Landed
# Arr,AC 8113,Air Canada,(SJC) San Jose,8:30 AM,Landed
# Arr,AC 561,Air Canada,(SFO) San Francisco,8:31 AM,Landed
# Arr,AV 6982^,AVIANCA,(SFO) San Francisco,8:31 AM,Landed
# Arr,NZ 4606^,Air New Zealand,(SFO) San Francisco,8:31 AM,Landed
# Arr,UA 8564^,United Airlines,(SFO) San Francisco,8:31 AM,Landed
# Arr,8P 604,Pacific Coastal Airlines,(YXC) Cranbrook,8:50 AM,Landed
# Arr,AC 101,Air Canada,(YYZ) Toronto,8:55 AM,Landed
# Arr,8P 550,Pacific Coastal Airlines,(YWL) Williams Lake,8:55 AM,Landed
# Arr,AC 8107,Air Canada,(DEN) Denver,8:56 AM,Landed
# Arr,WS 117,WestJet,(YYC) Calgary,8:56 AM,Landed
# Arr,HX 3627^,Hong Kong Airlines,(YYC) Calgary,8:56 AM,Landed
# Dep,Flight,Carrier,Destination,Departure,Status
# Dep,AC 8042,Air Canada,(SMF) Sacramento,9:05 AM,En Route
# Dep,AC 8055,Air Canada,(YYJ) Victoria,9:05 AM,Landed
# Dep,WS 1710,WestJet,(MCO) Orlando,9:10 AM,En Route
# Dep,JJ 4255^,LATAM Airlines Brasil,(MCO) Orlando,9:10 AM,En Route
# Dep,8P 763,Pacific Coastal Airlines,(YBL) Campbell River,9:15 AM,En Route
# Dep,WS 448,WestJet,(YWG) Winnipeg,9:15 AM,En Route
# Dep,AM 7360^,Aeromexico,(YWG) Winnipeg,9:15 AM,En Route
# Dep,AC 338,Air Canada,(YOW) Ottawa,9:20 AM,En Route
# Dep,WS 608,WestJet,(YOW) Ottawa,9:20 AM,En Route
# Dep,CI 9328^,China Airlines,(YOW) Ottawa,9:20 AM,En Route
# Dep,8P 107,Pacific Coastal Airlines,(YYJ) Victoria,9:30 AM,En Route
# Dep,AC 572,Air Canada,(LAX) Los Angeles,9:30 AM,En Route
# Dep,NZ 4615^,Air New Zealand,(LAX) Los Angeles,9:30 AM,En Route
# Dep,UA 8440^,United Airlines,(LAX) Los Angeles,9:30 AM,En Route
# Dep,VA 5152^,Virgin Australia,(LAX) Los Angeles,9:30 AM,En Route
# Dep,QK 9046,Jazz,(ZMT) Masset,9:30 AM,En Route
# Dep,AC 314,Air Canada,(YUL) Montreal,9:35 AM,Scheduled
# Dep,LH 6571^,Lufthansa,(YUL) Montreal,9:35 AM,Scheduled
# Dep,OS 8360^,Austrian,(YUL) Montreal,9:35 AM,Scheduled
# Dep,SN 9556^,Brussels Airlines,(YUL) Montreal,9:35 AM,Scheduled
# Dep,CX 855,Cathay Pacific,(HKG) Hong Kong,9:40 AM,Scheduled
# Dep,9M 562,Central Mountain Air,(YQZ) Quesnel,9:45 AM,Scheduled
# Dep,AC 6562^,Air Canada,(YQZ) Quesnel,9:45 AM,Scheduled
# Dep,AC 562,Air Canada,(ANC) Anchorage,9:50 AM,Scheduled
# Dep,AC 110,Air Canada,(YYZ) Toronto,10:00 AM,Scheduled
# Dep,OS 8298^,Austrian,(YYZ) Toronto,10:00 AM,Scheduled
# Dep,AC 208,Air Canada,(YYC) Calgary,10:00 AM,Scheduled
# Dep,WS 118,WestJet,(YYC) Calgary,10:00 AM,Scheduled
# Dep,AM 7122^,Aeromexico,(YYC) Calgary,10:00 AM,Scheduled
# Dep,CX 7032^,Cathay Pacific,(YYC) Calgary,10:00 AM,Scheduled
# Dep,DL 7046^,Delta Air Lines,(YYC) Calgary,10:00 AM,Scheduled
# Dep,HU 8888^,Hainan Airlines,(YYC) Calgary,10:00 AM,Scheduled
# Dep,KL 9679^,KLM,(YYC) Calgary,10:00 AM,Scheduled
# Dep,AC 8259,Air Canada,(YCD) Nanaimo,10:05 AM,Scheduled
# Dep,AC 8410,Air Canada,(YLW) Kelowna,10:10 AM,Scheduled
# Dep,AC 112,Air Canada,(YYZ) Toronto,10:10 AM,Scheduled
# Dep,LH 6701^,Lufthansa,(YYZ) Toronto,10:10 AM,Scheduled
# Dep,AC 8038,Air Canada,(ORD) Chicago,10:15 AM,Scheduled
# Dep,8P 453,Pacific Coastal Airlines,(YZZ) Trail,10:15 AM,Scheduled
# Dep,AC 8061,Air Canada,(YYJ) Victoria,10:15 AM,Scheduled
# Dep,8P 553,Pacific Coastal Airlines,(YWL) Williams Lake,10:20 AM,Scheduled
# Dep,WS 3355,WestJet,(YYJ) Victoria,10:25 AM,Scheduled
# Dep,F8* 257,Flair Airlines,(YYC) Calgary,10:30 AM,Scheduled
# Dep,8P 345,Pacific Coastal Airlines,(QBC) Bella Coola,10:30 AM,Scheduled
# Dep,AC 8248,Air Canada,(YCG) Castlegar,10:35 AM,Scheduled
# Dep,AC 8091,Air Canada,(SEA) Seattle,10:35 AM,Scheduled
# Dep,LH 6648^,Lufthansa,(SEA) Seattle,10:35 AM,Scheduled
# Dep,NZ 4597^,Air New Zealand,(SEA) Seattle,10:35 AM,Scheduled
# Dep,UA 8617^,United Airlines,(SEA) Seattle,10:35 AM,Scheduled
# Dep,UA 5996,United Airlines,(SFO) San Francisco,10:45 AM,Scheduled
# Dep,AC 5696^,Air Canada,(SFO) San Francisco,10:45 AM,Scheduled
# Dep,NZ 9998^,Air New Zealand,(SFO) San Francisco,10:45 AM,Scheduled
# Dep,AC 63,Air Canada,(ICN) Seoul,10:50 AM,Scheduled
# Dep,OZ 6101^,Asiana Airlines,(ICN) Seoul,10:50 AM,Scheduled
# Dep,SQ 1003^,Singapore Airlines,(ICN) Seoul,10:50 AM,Scheduled
#                                         Delayed"duled
#                                         Delayed"ipei,11:00 AM,"Scheduled
# Dep,WS 3320,WestJet,(YLW) Kelowna,11:00 AM,Scheduled
# Dep,CX 7014^,Cathay Pacific,(YLW) Kelowna,11:00 AM,Scheduled
# Dep,MU 8017^,China Eastern Airlines,(YLW) Kelowna,11:00 AM,Scheduled
# Dep,AC 8063,Air Canada,(YYJ) Victoria,11:00 AM,Scheduled
# Dep,AC 236,Air Canada,(YEG) Edmonton,11:00 AM,Scheduled
# Dep,TS 966,Air Transat,(YYZ) Toronto,11:00 AM,Scheduled
# Dep,WS 708,WestJet,(YYZ) Toronto,11:00 AM,Scheduled
# Dep,CX 7042^,Cathay Pacific,(YYZ) Toronto,11:00 AM,Scheduled
# Dep,MU 8005^,China Eastern Airlines,(YYZ) Toronto,11:00 AM,Scheduled
# Dep,AC 552,Air Canada,(LAX) Los Angeles,11:00 AM,Scheduled
# Dep,NZ 4603^,Air New Zealand,(LAX) Los Angeles,11:00 AM,Scheduled
# Dep,SQ 1004^,Singapore Airlines,(LAX) Los Angeles,11:00 AM,Scheduled
# Dep,UA 8098^,United Airlines,(LAX) Los Angeles,11:00 AM,Scheduled
# Dep,VA 5168^,Virgin Australia,(LAX) Los Angeles,11:00 AM,Scheduled
# Dep,AC 8412,Air Canada,(YLW) Kelowna,11:00 AM,Scheduled
# Dep,UA 2372,United Airlines,(ORD) Chicago,11:05 AM,Scheduled
# Dep,EI 6448^,Aer Lingus,(ORD) Chicago,11:05 AM,Scheduled
# Dep,AC 25,Air Canada,(PVG) Shanghai,11:10 AM,Scheduled
# Dep,AI 7329^,Air India,(PVG) Shanghai,11:10 AM,Scheduled
# Dep,CA 7456^,Air China,(PVG) Shanghai,11:10 AM,Scheduled
#                                         Delayed"heduled
#                                         Delayed"10 AM,"Scheduled
# Dep,9M 556,Central Mountain Air,(YWL) Williams Lake,11:10 AM,Scheduled
# Dep,AC 6556^,Air Canada,(YWL) Williams Lake,11:10 AM,Scheduled
# Dep,AC 1896,Air Canada,(LAS) Las Vegas,11:15 AM,Scheduled
# Dep,UA 8410^,United Airlines,(LAS) Las Vegas,11:15 AM,Scheduled
# Dep,8P 203,Pacific Coastal Airlines,(YPW) Powell River,11:15 AM,Scheduled
# Dep,4N 502,Air North,(YXY) Whitehorse,11:15 AM,Scheduled
# Dep,DL 5803,Delta Air Lines,(SEA) Seattle,11:16 AM,Scheduled
# Dep,KL 7773^,KLM,(SEA) Seattle,11:16 AM,Scheduled
# Dep,VS 5468^,Virgin Atlantic,(SEA) Seattle,11:16 AM,Scheduled
# Dep,WS 8057^,WestJet,(SEA) Seattle,11:16 AM,Scheduled
# Dep,AC 8490,Air Canada,(YYC) Calgary,11:30 AM,Scheduled
# Dep,AS 2044,Alaska Airlines,(SEA) Seattle,11:30 AM,Scheduled
# Dep,CX 7902^,Cathay Pacific,(SEA) Seattle,11:30 AM,Scheduled
# Dep,EK 3053^,Emirates,(SEA) Seattle,11:30 AM,Scheduled
# Dep,JL 6335^,JAL,(SEA) Seattle,11:30 AM,Scheduled
# Dep,8P 1611,Pacific Coastal Airlines,(YAZ) Tofino,11:30 AM,Scheduled
# Dep,AC 302,Air Canada,(YUL) Montreal,11:30 AM,Scheduled
# Dep,LH 6769^,Lufthansa,(YUL) Montreal,11:30 AM,Scheduled
# Dep,LX 4650^,SWISS,(YUL) Montreal,11:30 AM,Scheduled
# Dep,NZ 4828^,Air New Zealand,(YUL) Montreal,11:30 AM,Scheduled
# Dep,OZ 6106^,Asiana Airlines,(YUL) Montreal,11:30 AM,Scheduled
# Dep,DL 2443,Delta Air Lines,(DTW) Detroit,11:35 AM,Scheduled
# Dep,KL 7513^,KLM,(DTW) Detroit,11:35 AM,Scheduled
# Dep,VS 2987^,Virgin Atlantic,(DTW) Detroit,11:35 AM,Scheduled
# Dep,AC 8228,Air Canada,(PHX) Phoenix,11:40 AM,Scheduled
# Dep,UA 8166^,United Airlines,(PHX) Phoenix,11:40 AM,Scheduled
# Dep,UA 595,United Airlines,(SFO) San Francisco,11:48 AM,Scheduled
# Dep,AC 5110^,Air Canada,(SFO) San Francisco,11:48 AM,Scheduled
# Dep,NZ 9880^,Air New Zealand,(SFO) San Francisco,11:48 AM,Scheduled
# Arr,Flight,Carrier,Origin,Arrival,Status
# Arr,WS 701,WestJet,(YYZ) Toronto,9:03 AM,Landed
# Arr,CZ 7541^,China Southern Airlines,(YYZ) Toronto,9:03 AM,Landed
# Arr,HX 3617^,Hong Kong Airlines,(YYZ) Toronto,9:03 AM,Landed
# Arr,MU 8032^,China Eastern Airlines,(YYZ) Toronto,9:03 AM,Landed
# Arr,8P 862,Pacific Coastal Airlines,(YZT) Port Hardy,9:05 AM,Landed
#                                         Delayed"nded
# Arr,AC 8353,Air Canada,(YYF) Penticton,9:08 AM,Landed
# Arr,MU 581,China Eastern Airlines,(PVG) Shanghai,9:10 AM,Landed
# Arr,EY 1000^,Etihad Airways,(PVG) Shanghai,9:10 AM,Landed
# Arr,AC 357,Air Canada,(YOW) Ottawa,9:11 AM,Landed
# Arr,CA 7472^,Air China,(YOW) Ottawa,9:11 AM,Landed
# Arr,NH 6847^,ANA,(YOW) Ottawa,9:11 AM,Landed
# Arr,NZ 4789^,Air New Zealand,(YOW) Ottawa,9:11 AM,Landed
#                                         Delayed""En Route
#                                         Delayed":19 AM,"En Route
#                                         Delayed":19 AM,"En Route
#                                         Delayed"te
#                                         Delayed","En Route
#                                         Delayed" AM,"En Route
# Arr,AC 4,Air Canada,(NRT) Tokyo,9:25 AM,Landed
# Arr,AI 7328^,Air India,(NRT) Tokyo,9:25 AM,Landed
# Arr,NH 6814^,ANA,(NRT) Tokyo,9:25 AM,Landed
# Arr,SQ 1000^,Singapore Airlines,(NRT) Tokyo,9:25 AM,Landed
# Arr,TG 5837^,Thai Airways International,(NRT) Tokyo,9:25 AM,Landed
# Arr,8P 202,Pacific Coastal Airlines,(YPW) Powell River,9:35 AM,Landed
# Arr,F8* 258,Flair Airlines,(YYC) Calgary,9:35 AM,Landed
# Arr,AC 8667,Air Canada,(SAN) San Diego,9:35 AM,Landed
# Arr,AC 8039,Air Canada,(ORD) Chicago,9:40 AM,Landed
# Arr,WS 3157,WestJet,(YYJ) Victoria,9:42 AM,Landed
# Arr,AF 6576^,Air France,(YYJ) Victoria,9:42 AM,Landed
# Arr,CZ 7514^,China Southern Airlines,(YYJ) Victoria,9:42 AM,Landed
# Arr,HX 3645^,Hong Kong Airlines,(YYJ) Victoria,9:42 AM,Landed
# Arr,MU 8056^,China Eastern Airlines,(YYJ) Victoria,9:42 AM,Landed
# Arr,AC 301,Air Canada,(YUL) Montreal,9:43 AM,Landed
# Arr,CA 7468^,Air China,(YUL) Montreal,9:43 AM,Landed
# Arr,NH 6819^,ANA,(YUL) Montreal,9:43 AM,Landed
# Arr,NZ 4741^,Air New Zealand,(YUL) Montreal,9:43 AM,Landed
# Arr,OZ 6105^,Asiana Airlines,(YUL) Montreal,9:43 AM,Landed
# Arr,TK 9100^,Turkish Airlines,(YUL) Montreal,9:43 AM,Landed
# Arr,AC 1899,Air Canada,(LAS) Las Vegas,9:45 AM,En Route
# Arr,UA 8345^,United Airlines,(LAS) Las Vegas,9:45 AM,En Route
# Arr,AC 45,Air Canada,(DEL) Delhi,9:45 AM,En Route
# Arr,UA 8153^,United Airlines,(DEL) Delhi,9:45 AM,En Route
# Arr,AC 103,Air Canada,(YYZ) Toronto,9:49 AM,En Route
# Arr,AV 6904^,AVIANCA,(YYZ) Toronto,9:49 AM,En Route
#                                         Delayed""Landed
#                                         Delayed"Landed
# Arr,TS 981,Air Transat,(YYZ) Toronto,9:55 AM,En Route
# Arr,WS 119,WestJet,(YYC) Calgary,9:56 AM,En Route
# Arr,CZ 7533^,China Southern Airlines,(YYC) Calgary,9:56 AM,En Route
# Arr,HX 3629^,Hong Kong Airlines,(YYC) Calgary,9:56 AM,En Route
# Arr,MU 8010^,China Eastern Airlines,(YYC) Calgary,9:56 AM,En Route
# Arr,UA 5948,United Airlines,(SFO) San Francisco,10:00 AM,En Route
# Arr,AV 2360^,AVIANCA,(SFO) San Francisco,10:00 AM,En Route
# Arr,NZ 9997^,Air New Zealand,(SFO) San Francisco,10:00 AM,En Route
# Arr,AC 8247,Air Canada,(YCG) Castlegar,10:04 AM,En Route
# Arr,9M 589,Central Mountain Air,(YBL) Campbell River,10:10 AM,En Route
# Arr,AC 6589^,Air Canada,(YBL) Campbell River,10:10 AM,En Route
# Arr,HX 80,Hong Kong Airlines,(HKG) Hong Kong,10:10 AM,Landed
# Arr,EY 6275^,Etihad Airways,(HKG) Hong Kong,10:10 AM,Landed
# Arr,AC 807,Air Canada,(CDG) Paris,10:15 AM,En Route
# Arr,LH 6540^,Lufthansa,(CDG) Paris,10:15 AM,En Route
# Arr,UA 8447^,United Airlines,(CDG) Paris,10:15 AM,En Route
# Arr,4N 501,Air North,(YXY) Whitehorse,10:15 AM,En Route
# Arr,UA 468,United Airlines,(ORD) Chicago,10:19 AM,Landed
#                                         Delayed","En Route
#                                         Delayed"9 AM,"En Route
#                                         Delayed",10:19 AM,"En Route
#                                         Delayed"9 AM,"En Route
#                                         Delayed","En Route
# Arr,WS 3321,WestJet,(YLW) Kelowna,10:20 AM,En Route
# Arr,AF 3022^,Air France,(YLW) Kelowna,10:20 AM,En Route
# Arr,AM 7105^,Aeromexico,(YLW) Kelowna,10:20 AM,En Route
# Arr,CZ 7511^,China Southern Airlines,(YLW) Kelowna,10:20 AM,En Route
# Arr,HX 3631^,Hong Kong Airlines,(YLW) Kelowna,10:20 AM,En Route
# Arr,JL 5811^,JAL,(YLW) Kelowna,10:20 AM,En Route
# Arr,KE 6520^,Korean Air,(YLW) Kelowna,10:20 AM,En Route
# Arr,MU 8030^,China Eastern Airlines,(YLW) Kelowna,10:20 AM,En Route
# Arr,AC 8204,Air Canada,(YXS) Prince George,10:22 AM,En Route
# Arr,CA 7534^,Air China,(YXS) Prince George,10:22 AM,En Route
# Arr,LH 6704^,Lufthansa,(YXS) Prince George,10:22 AM,En Route
# Arr,NH 6829^,ANA,(YXS) Prince George,10:22 AM,En Route
# Arr,AC 8399,Air Canada,(YLW) Kelowna,10:25 AM,En Route
# Arr,CA 7510^,Air China,(YLW) Kelowna,10:25 AM,En Route
# Arr,LH 6493^,Lufthansa,(YLW) Kelowna,10:25 AM,En Route
# Arr,NZ 4523^,Air New Zealand,(YLW) Kelowna,10:25 AM,En Route
# Arr,DL 1123,Delta Air Lines,(DTW) Detroit,10:34 AM,En Route
# Arr,AC 8056,Air Canada,(YYJ) Victoria,10:34 AM,Scheduled
# Arr,CA 7506^,Air China,(YYJ) Victoria,10:34 AM,Scheduled
# Arr,AC 8308,Air Canada,(YQQ) Comox,10:40 AM,Scheduled
# Arr,AC 8493,Air Canada,(YYC) Calgary,10:41 AM,En Route
# Arr,DL 5708,Delta Air Lines,(SEA) Seattle,10:42 AM,En Route
# Arr,AF 2300^,Air France,(SEA) Seattle,10:42 AM,En Route
# Arr,WS 7080^,WestJet,(SEA) Seattle,10:42 AM,En Route
# Arr,AC 8839,Air Canada,(SFO) San Francisco,10:42 AM,En Route
# Arr,NZ 4610^,Air New Zealand,(SFO) San Francisco,10:42 AM,En Route
# Arr,AS 2898,Alaska Airlines,(SEA) Seattle,10:45 AM,Scheduled
# Arr,CX 7905^,Cathay Pacific,(SEA) Seattle,10:45 AM,Scheduled
# Arr,JL 6334^,JAL,(SEA) Seattle,10:45 AM,Scheduled
# Arr,KE 6155^,Korean Air,(SEA) Seattle,10:45 AM,Scheduled
# Arr,QF 3721^,Qantas,(SEA) Seattle,10:45 AM,Scheduled
# Arr,8P 108,Pacific Coastal Airlines,(YYJ) Victoria,10:45 AM,Scheduled
#                                         Delayed"duled
#                                         Delayed""Scheduled
#                                         Delayed""Scheduled
#                                         Delayed" AM,"Scheduled
#                                         Delayed"ton,10:48 AM,"Scheduled
#                                         Delayed""Scheduled
#                                         Delayed"on,10:48 AM,"Scheduled
# Arr,AC 105,Air Canada,(YYZ) Toronto,10:49 AM,En Route
#                                         Delayed"Route
#                                         Delayed"En Route
#                                         Delayed"ou,10:50 AM,"En Route
#                                         Delayed"50 AM,"En Route
# Arr,AC 8090,Air Canada,(SEA) Seattle,10:55 AM,Scheduled
# Arr,LH 6491^,Lufthansa,(SEA) Seattle,10:55 AM,Scheduled
# Arr,NZ 4588^,Air New Zealand,(SEA) Seattle,10:55 AM,Scheduled
# Arr,UA 8242^,United Airlines,(SEA) Seattle,10:55 AM,Scheduled
# Arr,WS 121,WestJet,(YYC) Calgary,10:56 AM,En Route
# Arr,AF 5126^,Air France,(YYC) Calgary,10:56 AM,En Route
# Arr,CZ 7537^,China Southern Airlines,(YYC) Calgary,10:56 AM,En Route
# Arr,MU 8044^,China Eastern Airlines,(YYC) Calgary,10:56 AM,En Route
# Arr,AC 239,Air Canada,(YEG) Edmonton,10:58 AM,En Route
# Arr,CA 7490^,Air China,(YEG) Edmonton,10:58 AM,En Route
# Arr,NZ 4505^,Air New Zealand,(YEG) Edmonton,10:58 AM,En Route
# Arr,AC 1565,Air Canada,(YUL) Montreal,10:59 AM,En Route
# Arr,CX 1509^,Cathay Pacific,(YUL) Montreal,10:59 AM,En Route
#                                         Delayed"1:02 AM,"En Route
#                                         Delayed"M,"En Route
#                                         Delayed",11:02 AM,"En Route
# Arr,WS 703,WestJet,(YYZ) Toronto,11:03 AM,En Route
# Arr,CZ 7543^,China Southern Airlines,(YYZ) Toronto,11:03 AM,En Route
# Arr,KE 6525^,Korean Air,(YYZ) Toronto,11:03 AM,En Route
# Arr,MU 8002^,China Eastern Airlines,(YYZ) Toronto,11:03 AM,En Route
# Arr,UA 475,United Airlines,(IAD) Dulles,11:08 AM,En Route
# Arr,AC 4812^,Air Canada,(IAD) Dulles,11:08 AM,En Route
# Arr,8P 764,Pacific Coastal Airlines,(YBL) Campbell River,11:10 AM,Scheduled
# Arr,AC 841,Air Canada,(FRA) Frankfurt,11:10 AM,En Route
# Arr,LH 6526^,Lufthansa,(FRA) Frankfurt,11:10 AM,En Route
# Arr,UA 8421^,United Airlines,(FRA) Frankfurt,11:10 AM,En Route
# Arr,UA 2249,United Airlines,(LAX) Los Angeles,11:14 AM,En Route
# Arr,AC 4152^,Air Canada,(LAX) Los Angeles,11:14 AM,En Route
# Arr,NZ 9993^,Air New Zealand,(LAX) Los Angeles,11:14 AM,En Route
# Arr,WS 615,WestJet,(YOW) Ottawa,11:16 AM,En Route
# Arr,AF 6590^,Air France,(YOW) Ottawa,11:16 AM,En Route
# Arr,CZ 7517^,China Southern Airlines,(YOW) Ottawa,11:16 AM,En Route
# Arr,JL 5717^,JAL,(YOW) Ottawa,11:16 AM,En Route
# Arr,KE 6578^,Korean Air,(YOW) Ottawa,11:16 AM,En Route
# Arr,MU 8062^,China Eastern Airlines,(YOW) Ottawa,11:16 AM,En Route
# Arr,QF 3402^,Qantas,(YOW) Ottawa,11:16 AM,En Route
#                                         Delayed"En Route
#                                         Delayed"AM,"En Route
#                                         Delayed"1:17 AM,"En Route
#                                         Delayed"AM,"En Route
#                                         Delayed"En Route
# Arr,WS 3282,WestJet,(YXS) Prince George,11:24 AM,Scheduled
# Arr,AF 6555^,Air France,(YXS) Prince George,11:24 AM,Scheduled
# Arr,AM 7107^,Aeromexico,(YXS) Prince George,11:24 AM,Scheduled
# Arr,DL 7122^,Delta Air Lines,(YXS) Prince George,11:24 AM,Scheduled
# Arr,JL 5721^,JAL,(YXS) Prince George,11:24 AM,Scheduled
# Arr,KE 6522^,Korean Air,(YXS) Prince George,11:24 AM,Scheduled
# Arr,MU 8008^,China Eastern Airlines,(YXS) Prince George,11:24 AM,Scheduled
# Arr,UA 2292,United Airlines,(DEN) Denver,11:25 AM,En Route
# Arr,AC 4079^,Air Canada,(DEN) Denver,11:25 AM,En Route
# Arr,AF 374,Air France,(CDG) Paris,11:25 AM,En Route
# Arr,AZ 2702^,Alitalia,(CDG) Paris,11:25 AM,En Route
# Arr,DL 8305^,Delta Air Lines,(CDG) Paris,11:25 AM,En Route
# Arr,KL 2219^,KLM,(CDG) Paris,11:25 AM,En Route
# Arr,VS 6794^,Virgin Atlantic,(CDG) Paris,11:25 AM,En Route
# Arr,AC 185,Air Canada,(YYZ) Toronto,11:25 AM,En Route
# Arr,AA 1415,American Airlines,(DFW) Dallas,11:30 AM,En Route
# Arr,AC 803,Air Canada,(ZRH) Zurich,11:30 AM,En Route
# Arr,LH 6522^,Lufthansa,(ZRH) Zurich,11:30 AM,En Route
# Arr,LX 4648^,SWISS,(ZRH) Zurich,11:30 AM,En Route
# Arr,UA 8342^,United Airlines,(ZRH) Zurich,11:30 AM,En Route
#                                         Delayed","En Route
# Arr,AC 8260,Air Canada,(YCD) Nanaimo,11:35 AM,Scheduled
# Arr,LH 6813^,Lufthansa,(YCD) Nanaimo,11:35 AM,Scheduled
# Arr,AC 855,Air Canada,(LHR) London,11:35 AM,En Route
# Arr,LH 6840^,Lufthansa,(LHR) London,11:35 AM,En Route
# Arr,NZ 4825^,Air New Zealand,(LHR) London,11:35 AM,En Route
# Arr,OS 8211^,Austrian,(LHR) London,11:35 AM,En Route
# Arr,SA 7304^,South African Airways,(LHR) London,11:35 AM,En Route
# Arr,UA 8581^,United Airlines,(LHR) London,11:35 AM,En Route
# Arr,UL 2855^,SriLankan Airlines,(LHR) London,11:35 AM,En Route
#                                         Delayed"Route
#                                         Delayed"n Route
# Arr,F8* 415,Flair Airlines,(YEG) Edmonton,11:40 AM,Scheduled
# Arr,AC 26,Air Canada,(PVG) Shanghai,11:40 AM,En Route
# Arr,AI 7330^,Air India,(PVG) Shanghai,11:40 AM,En Route
# Arr,CA 7455^,Air China,(PVG) Shanghai,11:40 AM,En Route
# Arr,AC 8062,Air Canada,(YYJ) Victoria,11:44 AM,Scheduled
# Arr,CA 7502^,Air China,(YYJ) Victoria,11:44 AM,Scheduled
# Arr,LH 6497^,Lufthansa,(YYJ) Victoria,11:44 AM,Scheduled
# Arr,LX 4689^,SWISS,(YYJ) Victoria,11:44 AM,Scheduled
# Arr,NZ 4563^,Air New Zealand,(YYJ) Victoria,11:44 AM,Scheduled
# Arr,UA 8462^,United Airlines,(YYJ) Victoria,11:44 AM,Scheduled
#                                         Delayed"
#                                         Delayed" AM,"En Route
#                                         Delayed" AM,"En Route
# Arr,AC 297,Air Canada,(YWG) Winnipeg,11:49 AM,En Route
# Arr,CA 7476^,Air China,(YWG) Winnipeg,11:49 AM,En Route
# Arr,CX 1527^,Cathay Pacific,(YWG) Winnipeg,11:49 AM,En Route
# Arr,NH 6849^,ANA,(YWG) Winnipeg,11:49 AM,En Route
#                                         Delayed"oute
#                                         Delayed"ipei,11:50 AM,"En Route
# Arr,WS 123,WestJet,(YYC) Calgary,11:56 AM,Scheduled
# Arr,AF 5127^,Air France,(YYC) Calgary,11:56 AM,Scheduled
# Arr,AM 7126^,Aeromexico,(YYC) Calgary,11:56 AM,Scheduled
# Arr,KE 6504^,Korean Air,(YYC) Calgary,11:56 AM,Scheduled
# Arr,AC 213,Air Canada,(YYC) Calgary,11:56 AM,Scheduled
# Arr,CA 7482^,Air China,(YYC) Calgary,11:56 AM,Scheduled
# Arr,LX 4666^,SWISS,(YYC) Calgary,11:56 AM,Scheduled
# Arr,AC 8122,Air Canada,(PDX) Portland,11:58 AM,Scheduled
# Arr,NH 5393^,ANA,(PDX) Portland,11:58 AM,Scheduled
# Arr,UA 8218^,United Airlines,(PDX) Portland,11:58 AM,Scheduled
# Arr,AC 107,Air Canada,(YYZ) Toronto,11:58 AM,En Route
# Arr,CA 7464^,Air China,(YYZ) Toronto,11:58 AM,En Route
# Arr,NZ 4729^,Air New Zealand,(YYZ) Toronto,11:58 AM,En Route
# Arr,NTA 201,Northern Thunderbird Air,(YXS) Prince George,,En Route
# Dep,Flight,Carrier,Destination,Departure,Status
# Dep,WS 3161,WestJet,(YCD) Nanaimo,12:05 PM,Scheduled
# Dep,UA 1241,United Airlines,(IAD) Dulles,12:05 PM,Scheduled
# Dep,AC 4813^,Air Canada,(IAD) Dulles,12:05 PM,Scheduled
# Dep,UA 1184,United Airlines,(DEN) Denver,12:15 PM,Scheduled
# Dep,AC 8194,Air Canada,(YKA) Kamloops,12:20 PM,Scheduled
# Dep,NZ 4564^,Air New Zealand,(YKA) Kamloops,12:20 PM,Scheduled
# Dep,AC 8261,Air Canada,(YCD) Nanaimo,12:20 PM,Scheduled
# Dep,AA 979,American Airlines,(ORD) Chicago,12:28 PM,Scheduled
# Dep,AC 212,Air Canada,(YYC) Calgary,12:30 PM,Scheduled
# Dep,CA 7479^,Air China,(YYC) Calgary,12:30 PM,Scheduled
# Dep,LH 6552^,Lufthansa,(YYC) Calgary,12:30 PM,Scheduled
# Dep,UA 1923,United Airlines,(LAX) Los Angeles,12:35 PM,Scheduled
# Dep,AC 4153^,Air Canada,(LAX) Los Angeles,12:35 PM,Scheduled
# Dep,NZ 9995^,Air New Zealand,(LAX) Los Angeles,12:35 PM,Scheduled
# Dep,WS 482,WestJet,(YWG) Winnipeg,12:35 PM,Scheduled
# Dep,CX 7054^,Cathay Pacific,(YWG) Winnipeg,12:35 PM,Scheduled
# Dep,CZ 7524^,China Southern Airlines,(YWG) Winnipeg,12:35 PM,Scheduled
# Dep,HX 3638^,Hong Kong Airlines,(YWG) Winnipeg,12:35 PM,Scheduled
# Dep,MU 8013^,China Eastern Airlines,(YWG) Winnipeg,12:35 PM,Scheduled
# Dep,QF 3364^,Qantas,(YWG) Winnipeg,12:35 PM,Scheduled
# Dep,WS 1774,WestJet,(SFO) San Francisco,12:35 PM,Scheduled
# Dep,DL 7054^,Delta Air Lines,(SFO) San Francisco,12:35 PM,Scheduled
# Dep,QF 3380^,Qantas,(SFO) San Francisco,12:35 PM,Scheduled
# Dep,AC 184,Air Canada,(YYZ) Toronto,12:40 PM,Scheduled
# Dep,CA 7463^,Air China,(YYZ) Toronto,12:40 PM,Scheduled
# Dep,LH 6807^,Lufthansa,(YYZ) Toronto,12:40 PM,Scheduled
# Dep,OS 8299^,Austrian,(YYZ) Toronto,12:40 PM,Scheduled
# Dep,TK 9137^,Turkish Airlines,(YYZ) Toronto,12:40 PM,Scheduled
# Dep,F8* 416,Flair Airlines,(YEG) Edmonton,12:40 PM,Scheduled
# Dep,CZ 330,China Southern Airlines,(CAN) Guangzhou,12:50 PM,Scheduled
# Dep,MF 9274^,Xiamen Airlines,(CAN) Guangzhou,12:50 PM,Scheduled
# Dep,AC 8414,Air Canada,(YLW) Kelowna,12:50 PM,Scheduled
# Dep,CA 7507^,Air China,(YLW) Kelowna,12:50 PM,Scheduled
# Dep,LH 6650^,Lufthansa,(YLW) Kelowna,12:50 PM,Scheduled
# Dep,NZ 4576^,Air New Zealand,(YLW) Kelowna,12:50 PM,Scheduled
# Dep,AC 8085,Air Canada,(YYJ) Victoria,12:55 PM,Scheduled
# Dep,CA 7503^,Air China,(YYJ) Victoria,12:55 PM,Scheduled
# Dep,LH 6514^,Lufthansa,(YYJ) Victoria,12:55 PM,Scheduled
# Dep,LX 4686^,SWISS,(YYJ) Victoria,12:55 PM,Scheduled
# Dep,AC 1566,Air Canada,(YUL) Montreal,1:00 PM,Scheduled
# Dep,CA 7469^,Air China,(YUL) Montreal,1:00 PM,Scheduled
# Dep,AC 802,Air Canada,(ZRH) Zurich,1:00 PM,Scheduled
# Dep,LH 6505^,Lufthansa,(ZRH) Zurich,1:00 PM,Scheduled
# Dep,LX 4665^,SWISS,(ZRH) Zurich,1:00 PM,Scheduled
# Dep,UA 8343^,United Airlines,(ZRH) Zurich,1:00 PM,Scheduled
# Dep,WS 714,WestJet,(YYZ) Toronto,1:00 PM,Scheduled
# Dep,AF 3762^,Air France,(YYZ) Toronto,1:00 PM,Scheduled
# Dep,CZ 7542^,China Southern Airlines,(YYZ) Toronto,1:00 PM,Scheduled
# Dep,HX 3618^,Hong Kong Airlines,(YYZ) Toronto,1:00 PM,Scheduled
# Dep,QF 3374^,Qantas,(YYZ) Toronto,1:00 PM,Scheduled
# Dep,WS 3322,WestJet,(YLW) Kelowna,1:00 PM,Scheduled
# Dep,AF 6578^,Air France,(YLW) Kelowna,1:00 PM,Scheduled
# Dep,CZ 7512^,China Southern Airlines,(YLW) Kelowna,1:00 PM,Scheduled
# Dep,DL 7082^,Delta Air Lines,(YLW) Kelowna,1:00 PM,Scheduled
# Dep,HX 3630^,Hong Kong Airlines,(YLW) Kelowna,1:00 PM,Scheduled
# Dep,QF 3410^,Qantas,(YLW) Kelowna,1:00 PM,Scheduled
# Dep,DL 5817,Delta Air Lines,(SEA) Seattle,1:00 PM,Scheduled
# Dep,AF 2315^,Air France,(SEA) Seattle,1:00 PM,Scheduled
# Dep,VS 5263^,Virgin Atlantic,(SEA) Seattle,1:00 PM,Scheduled
# Dep,WS 7139^,WestJet,(SEA) Seattle,1:00 PM,Scheduled
# Dep,8P 755,Pacific Coastal Airlines,(YBL) Campbell River,1:00 PM,Scheduled
# Dep,WS 124,WestJet,(YYC) Calgary,1:00 PM,Scheduled
# Dep,AF 3756^,Air France,(YYC) Calgary,1:00 PM,Scheduled
# Dep,CZ 7507^,China Southern Airlines,(YYC) Calgary,1:00 PM,Scheduled
# Dep,HX 3626^,Hong Kong Airlines,(YYC) Calgary,1:00 PM,Scheduled
# Dep,LA 5219^,LATAM Airlines,(YYC) Calgary,1:00 PM,Scheduled
# Dep,MU 8041^,China Eastern Airlines,(YYC) Calgary,1:00 PM,Scheduled
# Dep,QF 3417^,Qantas,(YYC) Calgary,1:00 PM,Scheduled
# Dep,AC 8522,Air Canada,(YZP) Sandspit,1:05 PM,Scheduled
# Dep,DL 2898,Delta Air Lines,(SLC) Salt Lake City,1:09 PM,Scheduled
# Dep,AF 8960^,Air France,(SLC) Salt Lake City,1:09 PM,Scheduled
# Dep,CZ 1231^,China Southern Airlines,(SLC) Salt Lake City,1:09 PM,Scheduled
# Dep,VS 3604^,Virgin Atlantic,(SLC) Salt Lake City,1:09 PM,Scheduled
# Dep,WS 6406^,WestJet,(SLC) Salt Lake City,1:09 PM,Scheduled
# Dep,AC 39,Air Canada,(KIX) Osaka,1:10 PM,Scheduled
# Dep,AC 7,Air Canada,(HKG) Hong Kong,1:10 PM,Scheduled
# Dep,AI 7325^,Air India,(HKG) Hong Kong,1:10 PM,Scheduled
# Dep,SA 7307^,South African Airways,(HKG) Hong Kong,1:10 PM,Scheduled
# Dep,TG 5867^,Thai Airways International,(HKG) Hong Kong,1:10 PM,Scheduled
# Dep,UL 2007^,SriLankan Airlines,(HKG) Hong Kong,1:10 PM,Scheduled
# Dep,AC 116,Air Canada,(YYZ) Toronto,1:15 PM,Scheduled
# Dep,CA 7465^,Air China,(YYZ) Toronto,1:15 PM,Scheduled
# Dep,OZ 6108^,Asiana Airlines,(YYZ) Toronto,1:15 PM,Scheduled
# Dep,WS 3285,WestJet,(YXS) Prince George,1:15 PM,Scheduled
# Dep,AF 6574^,Air France,(YXS) Prince George,1:15 PM,Scheduled
# Dep,CZ 7549^,China Southern Airlines,(YXS) Prince George,1:15 PM,Scheduled
# Dep,DL 7004^,Delta Air Lines,(YXS) Prince George,1:15 PM,Scheduled
# Dep,HX 3642^,Hong Kong Airlines,(YXS) Prince George,1:15 PM,Scheduled
# Dep,JL 5720^,JAL,(YXS) Prince George,1:15 PM,Scheduled
# Dep,MU 8039^,China Eastern Airlines,(YXS) Prince George,1:15 PM,Scheduled
# Dep,KE 278,Korean Air,(ICN) Seoul,1:15 PM,Scheduled
# Dep,AA 1415,American Airlines,(DFW) Dallas,1:15 PM,Scheduled
# Dep,BA 6502^,British Airways,(DFW) Dallas,1:15 PM,Scheduled
# Dep,QF 4474^,Qantas,(DFW) Dallas,1:15 PM,Scheduled
# Dep,AC 538,Air Canada,(ANC) Anchorage,1:15 PM,Scheduled
# Dep,UA 2057,United Airlines,(IAH) Houston,1:16 PM,Scheduled
# Dep,AC 5097^,Air Canada,(IAH) Houston,1:16 PM,Scheduled
# Dep,NZ 9976^,Air New Zealand,(IAH) Houston,1:16 PM,Scheduled
# Dep,AA 6014,American Airlines,(LAX) Los Angeles,1:18 PM,Scheduled
# Dep,AS 4032^,Alaska Airlines,(LAX) Los Angeles,1:18 PM,Scheduled
# Dep,QF 4558^,Qantas,(LAX) Los Angeles,1:18 PM,Scheduled
# Dep,MU 582,China Eastern Airlines,(PVG) Shanghai,1:20 PM,Scheduled
# Dep,EY 1002^,Etihad Airways,(PVG) Shanghai,1:20 PM,Scheduled
# Dep,AC 840,Air Canada,(FRA) Frankfurt,1:25 PM,Scheduled
# Dep,LH 6527^,Lufthansa,(FRA) Frankfurt,1:25 PM,Scheduled
# Dep,UA 8420^,United Airlines,(FRA) Frankfurt,1:25 PM,Scheduled
# Dep,AC 8562,Air Canada,(YYD) Smithers,1:25 PM,Scheduled
# Dep,AF 379,Air France,(CDG) Paris,1:25 PM,Scheduled
# Dep,AZ 2701^,Alitalia,(CDG) Paris,1:25 PM,Scheduled
# Dep,DL 8306^,Delta Air Lines,(CDG) Paris,1:25 PM,Scheduled
# Dep,KL 2442^,KLM,(CDG) Paris,1:25 PM,Scheduled
# Dep,VS 6799^,Virgin Atlantic,(CDG) Paris,1:25 PM,Scheduled
# Dep,9M 590,Central Mountain Air,(YBL) Campbell River,1:30 PM,Scheduled
# Dep,AC 6590^,Air Canada,(YBL) Campbell River,1:30 PM,Scheduled
# Dep,AS 2415,Alaska Airlines,(PDX) Portland,1:30 PM,Scheduled
# Dep,AA 7599^,American Airlines,(PDX) Portland,1:30 PM,Scheduled
# Dep,JL 5419^,JAL,(PDX) Portland,1:30 PM,Scheduled
# Dep,KE 6177^,Korean Air,(PDX) Portland,1:30 PM,Scheduled
# Dep,AC 8125,Air Canada,(PDX) Portland,1:30 PM,Scheduled
# Dep,NZ 4757^,Air New Zealand,(PDX) Portland,1:30 PM,Scheduled
# Dep,UA 8221^,United Airlines,(PDX) Portland,1:30 PM,Scheduled
# Dep,AC 566,Air Canada,(SFO) San Francisco,1:30 PM,Scheduled
# Dep,NZ 4599^,Air New Zealand,(SFO) San Francisco,1:30 PM,Scheduled
# Dep,UA 298,United Airlines,(ORD) Chicago,1:35 PM,Scheduled
# Dep,AC 4876^,Air Canada,(ORD) Chicago,1:35 PM,Scheduled
# Dep,AC 8097,Air Canada,(SEA) Seattle,1:40 PM,Scheduled
# Dep,LH 6510^,Lufthansa,(SEA) Seattle,1:40 PM,Scheduled
# Dep,NZ 4755^,Air New Zealand,(SEA) Seattle,1:40 PM,Scheduled
# Dep,UA 8395^,United Airlines,(SEA) Seattle,1:40 PM,Scheduled
# Dep,AC 186,Air Canada,(YYZ) Toronto,1:45 PM,Scheduled
# Dep,LO 4138^,LOT - Polish Airlines,(YYZ) Toronto,1:45 PM,Scheduled
# Dep,AC 8574,Air Canada,(YXE) Saskatoon,1:50 PM,Scheduled
# Dep,CA 7513^,Air China,(YXE) Saskatoon,1:50 PM,Scheduled
# Dep,CA 992,Air China,(PEK) Beijing,1:50 PM,Scheduled
# Dep,AC 6601^,Air Canada,(PEK) Beijing,1:50 PM,Scheduled
# Dep,AC 292,Air Canada,(YWG) Winnipeg,1:50 PM,Scheduled
# Dep,CA 7475^,Air China,(YWG) Winnipeg,1:50 PM,Scheduled
#                                         Delayed"ed
#                                         Delayed"duled
#                                         Delayed"
#                                         Delayed" PM,"Scheduled
#                                         Delayed"kyo,1:50 PM,"Scheduled
# Dep,UA 1743,United Airlines,(SFO) San Francisco,1:59 PM,Scheduled
# Dep,CM 1126^,Copa Airlines,(SFO) San Francisco,1:59 PM,Scheduled
# Dep,NZ 9878^,Air New Zealand,(SFO) San Francisco,1:59 PM,Scheduled
# Dep,8P 209,Pacific Coastal Airlines,(YPW) Powell River,2:00 PM,Scheduled
# Dep,WS 614,WestJet,(YOW) Ottawa,2:00 PM,Scheduled
# Dep,AF 6589^,Air France,(YOW) Ottawa,2:00 PM,Scheduled
# Dep,CZ 7518^,China Southern Airlines,(YOW) Ottawa,2:00 PM,Scheduled
# Dep,JL 5716^,JAL,(YOW) Ottawa,2:00 PM,Scheduled
# Dep,MU 8019^,China Eastern Airlines,(YOW) Ottawa,2:00 PM,Scheduled
# Dep,QF 3400^,Qantas,(YOW) Ottawa,2:00 PM,Scheduled
# Dep,DL 1677,Delta Air Lines,(MSP) Minneapolis,2:00 PM,Scheduled
# Dep,CZ 1221^,China Southern Airlines,(MSP) Minneapolis,2:00 PM,Scheduled
# Dep,KL 8023^,KLM,(MSP) Minneapolis,2:00 PM,Scheduled
# Dep,WS 6388^,WestJet,(MSP) Minneapolis,2:00 PM,Scheduled
# Dep,WS 126,WestJet,(YYC) Calgary,2:00 PM,Scheduled
# Dep,AF 3016^,Air France,(YYC) Calgary,2:00 PM,Scheduled
# Dep,CZ 7505^,China Southern Airlines,(YYC) Calgary,2:00 PM,Scheduled
# Dep,HX 3628^,Hong Kong Airlines,(YYC) Calgary,2:00 PM,Scheduled
# Dep,JL 5800^,JAL,(YYC) Calgary,2:00 PM,Scheduled
# Dep,AC 8572,Air Canada,(YQR) Regina,2:00 PM,Scheduled
# Dep,CA 7517^,Air China,(YQR) Regina,2:00 PM,Scheduled
# Dep,WS 180,WestJet,(YEG) Edmonton,2:00 PM,Scheduled
# Dep,AF 6579^,Air France,(YEG) Edmonton,2:00 PM,Scheduled
# Dep,CX 7000^,Cathay Pacific,(YEG) Edmonton,2:00 PM,Scheduled
# Dep,CZ 7504^,China Southern Airlines,(YEG) Edmonton,2:00 PM,Scheduled
# Dep,DL 7068^,Delta Air Lines,(YEG) Edmonton,2:00 PM,Scheduled
# Dep,HX 3612^,Hong Kong Airlines,(YEG) Edmonton,2:00 PM,Scheduled
# Dep,JL 5802^,JAL,(YEG) Edmonton,2:00 PM,Scheduled
# Dep,KL 9818^,KLM,(YEG) Edmonton,2:00 PM,Scheduled
# Dep,MU 8055^,China Eastern Airlines,(YEG) Edmonton,2:00 PM,Scheduled
# Dep,QF 3459^,Qantas,(YEG) Edmonton,2:00 PM,Scheduled
# Dep,AC 8069,Air Canada,(YYJ) Victoria,2:05 PM,Scheduled
# Dep,CA 7501^,Air China,(YYJ) Victoria,2:05 PM,Scheduled
# Dep,AC 8668,Air Canada,(SAN) San Diego,2:05 PM,Scheduled
# Dep,WS 3269,WestJet,(YQQ) Comox,2:10 PM,Scheduled
# Dep,TS 408,Air Transat,(CDG) Paris,2:10 PM,Scheduled
# Dep,AC 242,Air Canada,(YEG) Edmonton,2:10 PM,Scheduled
# Dep,CA 7485^,Air China,(YEG) Edmonton,2:10 PM,Scheduled
# Dep,AC 118,Air Canada,(YYZ) Toronto,2:10 PM,Scheduled
# Dep,NZ 4802^,Air New Zealand,(YYZ) Toronto,2:10 PM,Scheduled
# Dep,OS 8303^,Austrian,(YYZ) Toronto,2:10 PM,Scheduled
# ...
# Arr,LX 4674^,SWISS,(YUL) Montreal,6:39 PM,Scheduled
# Arr,OS 8321^,Austrian,(YUL) Montreal,6:39 PM,Scheduled
# Arr,SN 9555^,Brussels Airlines,(YUL) Montreal,6:39 PM,Scheduled
# Arr,AS 2838,Alaska Airlines,(PDX) Portland,6:40 PM,Scheduled
# Arr,AA 7617^,American Airlines,(PDX) Portland,6:40 PM,Scheduled
# Arr,MF 805,Xiamen Airlines,(XMN) Xiamen,6:40 PM,En Route
# Arr,CZ 4019^,China Southern Airlines,(XMN) Xiamen,6:40 PM,En Route
# Arr,EDW 10,Edelweiss Air,(ZRH) Zurich,6:50 PM,En Route
# Arr,LX 8010^,SWISS,(ZRH) Zurich,6:50 PM,En Route
# Arr,WS 3329,WestJet,(YLW) Kelowna,6:55 PM,Scheduled
# Arr,AM 7357^,Aeromexico,(YLW) Kelowna,6:55 PM,Scheduled
# Arr,QF 3425^,Qantas,(YLW) Kelowna,6:55 PM,Scheduled
#                                         Delayed"
#                                         Delayed"
#                                         Delayed"
#                                         Delayed"
#                                         Delayed"
# Arr,AC 121,Air Canada,(YYZ) Toronto,6:55 PM,Scheduled
# Arr,AV 6910^,AVIANCA,(YYZ) Toronto,6:55 PM,Scheduled
# Arr,NZ 4771^,Air New Zealand,(YYZ) Toronto,6:55 PM,Scheduled
# Arr,OS 8245^,Austrian,(YYZ) Toronto,6:55 PM,Scheduled
# Arr,AC 8569,Air Canada,(YQR) Regina,6:55 PM,Scheduled
# Arr,AC 8186,Air Canada,(YXJ) Fort St. John,7:00 PM,Scheduled
# Arr,WS 711,WestJet,(YYZ) Toronto,7:03 PM,Scheduled
# Arr,DL 7186^,Delta Air Lines,(YYZ) Toronto,7:03 PM,Scheduled
# Arr,WS 3184,WestJet,(YYJ) Victoria,7:12 PM,Scheduled
# Arr,AM 7364^,Aeromexico,(YYJ) Victoria,7:12 PM,Scheduled
# Arr,CI 9357^,China Airlines,(YYJ) Victoria,7:12 PM,Scheduled
# Arr,MU 8054^,China Eastern Airlines,(YYJ) Victoria,7:12 PM,Scheduled
# Arr,PR 1953^,Philippine Airlines,(YYJ) Victoria,7:12 PM,Scheduled
# Arr,AC 571,Air Canada,(SFO) San Francisco,7:15 PM,Scheduled
# Arr,NZ 4608^,Air New Zealand,(SFO) San Francisco,7:15 PM,Scheduled
# Arr,4N 535,Air North,(YXY) Whitehorse,7:15 PM,Scheduled
# Arr,AC 971,Air Canada,(PVR) Puerto Vallarta,7:15 PM,Scheduled
# Arr,AA 2263,American Airlines,(DFW) Dallas,7:18 PM,Scheduled
# Arr,BA 4996^,British Airways,(DFW) Dallas,7:18 PM,Scheduled
# Arr,QF 4469^,Qantas,(DFW) Dallas,7:18 PM,Scheduled
# Arr,CI 32,China Airlines,(TPE) Taipei,7:20 PM,En Route
# Arr,VN 2034^,Vietnam Airlines,(TPE) Taipei,7:20 PM,En Route
# Arr,CA 997,Air China,(PEK) Beijing,7:20 PM,En Route
# Arr,AC 6602^,Air Canada,(PEK) Beijing,7:20 PM,En Route
# Arr,AC 307,Air Canada,(YUL) Montreal,7:24 PM,Scheduled
# Arr,LX 4672^,SWISS,(YUL) Montreal,7:24 PM,Scheduled
# Arr,NZ 4767^,Air New Zealand,(YUL) Montreal,7:24 PM,Scheduled
# Arr,TS 4431,Air Transat,(PVR) Puerto Vallarta,7:30 PM,Scheduled
# Arr,AC 8041,Air Canada,(ORD) Chicago,7:30 PM,Scheduled
# Arr,UA 8192^,United Airlines,(ORD) Chicago,7:30 PM,Scheduled
# Arr,AC 8098,Air Canada,(SEA) Seattle,7:31 PM,Scheduled
# Arr,NZ 4756^,Air New Zealand,(SEA) Seattle,7:31 PM,Scheduled
# Arr,UA 8250^,United Airlines,(SEA) Seattle,7:31 PM,Scheduled
# Arr,WS 697,WestJet,(YWG) Winnipeg,7:34 PM,Scheduled
# Arr,AM 7361^,Aeromexico,(YWG) Winnipeg,7:34 PM,Scheduled
# Arr,CX 7017^,Cathay Pacific,(YWG) Winnipeg,7:34 PM,Scheduled
# Arr,DL 7636^,Delta Air Lines,(YWG) Winnipeg,7:34 PM,Scheduled
# Arr,MU 8050^,China Eastern Airlines,(YWG) Winnipeg,7:34 PM,Scheduled
# Arr,PR 1913^,Philippine Airlines,(YWG) Winnipeg,7:34 PM,Scheduled
# Arr,BR 10,EVA Air,(TPE) Taipei,7:40 PM,En Route
# Arr,SQ 5810^,Singapore Airlines,(TPE) Taipei,7:40 PM,En Route
# Arr,TG 6344^,Thai Airways International,(TPE) Taipei,7:40 PM,En Route
# Arr,AC 8858,Air Canada,(YXY) Whitehorse,7:43 PM,Scheduled
# Arr,AC 8218,Air Canada,(YXC) Cranbrook,7:45 PM,Scheduled
# Arr,WS 3203,WestJet,(YXJ) Fort St. John,7:49 PM,Scheduled
# Arr,AM 7372^,Aeromexico,(YXJ) Fort St. John,7:49 PM,Scheduled
# Arr,KL 9611^,KLM,(YXJ) Fort St. John,7:49 PM,Scheduled
# Arr,MU 597,China Eastern Airlines,(PVG) Shanghai,7:50 PM,En Route
# Arr,EY 1001^,Etihad Airways,(PVG) Shanghai,7:50 PM,En Route
# Arr,WS 137,WestJet,(YYC) Calgary,7:56 PM,Scheduled
# Arr,AM 7349^,Aeromexico,(YYC) Calgary,7:56 PM,Scheduled
# Arr,CI 9323^,China Airlines,(YYC) Calgary,7:56 PM,Scheduled
# Arr,CX 7035^,Cathay Pacific,(YYC) Calgary,7:56 PM,Scheduled
# Arr,LA 5191^,LATAM Airlines,(YYC) Calgary,7:56 PM,Scheduled
# Arr,MU 8012^,China Eastern Airlines,(YYC) Calgary,7:56 PM,Scheduled
# Arr,PR 1915^,Philippine Airlines,(YYC) Calgary,7:56 PM,Scheduled
# Arr,AC 345,Air Canada,(YOW) Ottawa,8:01 PM,Scheduled
# Arr,NZ 4819^,Air New Zealand,(YOW) Ottawa,8:01 PM,Scheduled
# Arr,WS 609,WestJet,(YOW) Ottawa,8:01 PM,Scheduled
# Arr,CI 9333^,China Airlines,(YOW) Ottawa,8:01 PM,Scheduled
# Arr,MU 8020^,China Eastern Airlines,(YOW) Ottawa,8:01 PM,Scheduled
# Arr,AA 2664,American Airlines,(PHX) Phoenix,8:01 PM,Scheduled
# Arr,AC 8126,Air Canada,(PDX) Portland,8:13 PM,Scheduled
# Arr,NZ 4812^,Air New Zealand,(PDX) Portland,8:13 PM,Scheduled
# Arr,UA 8224^,United Airlines,(PDX) Portland,8:13 PM,Scheduled
# Arr,AC 299,Air Canada,(YWG) Winnipeg,8:19 PM,Scheduled
# Arr,AC 539,Air Canada,(ANC) Anchorage,8:32 PM,Scheduled
# Arr,AC 8078,Air Canada,(YYJ) Victoria,8:34 PM,Scheduled
# Arr,AC 8669,Air Canada,(SAN) San Diego,8:40 PM,Scheduled
# Arr,AC 309,Air Canada,(YUL) Montreal,8:41 PM,Scheduled
# Arr,LH 6663^,Lufthansa,(YUL) Montreal,8:41 PM,Scheduled
# Arr,NZ 4747^,Air New Zealand,(YUL) Montreal,8:41 PM,Scheduled
# Arr,OS 8343^,Austrian,(YUL) Montreal,8:41 PM,Scheduled
# Arr,AC 123,Air Canada,(YYZ) Toronto,8:44 PM,Scheduled
# Arr,AV 6908^,AVIANCA,(YYZ) Toronto,8:44 PM,Scheduled
# Arr,EI 8547^,Aer Lingus,(YYZ) Toronto,8:44 PM,Scheduled
# Arr,LH 6580^,Lufthansa,(YYZ) Toronto,8:44 PM,Scheduled
# Arr,WS 3298,WestJet,(YXS) Prince George,8:49 PM,Scheduled
# Arr,AM 7376^,Aeromexico,(YXS) Prince George,8:49 PM,Scheduled
# Arr,CI 9353^,China Airlines,(YXS) Prince George,8:49 PM,Scheduled
# Arr,MU 8058^,China Eastern Airlines,(YXS) Prince George,8:49 PM,Scheduled
# Arr,PR 1965^,Philippine Airlines,(YXS) Prince George,8:49 PM,Scheduled
# Arr,AC 8357,Air Canada,(YYF) Penticton,8:55 PM,Scheduled
# Dep,Flight,Carrier,Destination,Departure,Status
# Dep,AC 8311,Air Canada,(YQQ) Comox,9:10 PM,Scheduled
# Dep,WS 142,WestJet,(YYC) Calgary,9:15 PM,Scheduled
# Dep,CI 9344^,China Airlines,(YYC) Calgary,9:15 PM,Scheduled
# Dep,WS 186,WestJet,(YEG) Edmonton,9:15 PM,Scheduled
# Dep,CI 9316^,China Airlines,(YEG) Edmonton,9:15 PM,Scheduled
# Dep,CX 7002^,Cathay Pacific,(YEG) Edmonton,9:15 PM,Scheduled
# Dep,KL 9638^,KLM,(YEG) Edmonton,9:15 PM,Scheduled
# Dep,PR 1906^,Philippine Airlines,(YEG) Edmonton,9:15 PM,Scheduled
# Dep,WS 3317,WestJet,(YCD) Nanaimo,9:30 PM,Scheduled
# Dep,WS 3287,WestJet,(YXS) Prince George,9:45 PM,Scheduled
# Dep,CI 9352^,China Airlines,(YXS) Prince George,9:45 PM,Scheduled
# Dep,MU 8053^,China Eastern Airlines,(YXS) Prince George,9:45 PM,Scheduled
# Dep,PR 1940^,Philippine Airlines,(YXS) Prince George,9:45 PM,Scheduled
# Dep,WS 3310,WestJet,(YLW) Kelowna,9:50 PM,Scheduled
# Dep,MU 8015^,China Eastern Airlines,(YLW) Kelowna,9:50 PM,Scheduled
# Dep,WS 3185,WestJet,(YYJ) Victoria,10:00 PM,Scheduled
# Dep,CI 9356^,China Airlines,(YYJ) Victoria,10:00 PM,Scheduled
# Dep,DL 7016^,Delta Air Lines,(YYJ) Victoria,10:00 PM,Scheduled
# Dep,MU 8049^,China Eastern Airlines,(YYJ) Victoria,10:00 PM,Scheduled
# Dep,PR 1958^,Philippine Airlines,(YYJ) Victoria,10:00 PM,Scheduled
# Dep,AC 252,Air Canada,(YEG) Edmonton,10:30 PM,Scheduled
# Dep,BR 3086^,EVA Air,(YEG) Edmonton,10:30 PM,Scheduled
# Dep,CA 7489^,Air China,(YEG) Edmonton,10:30 PM,Scheduled
# Dep,AC 126,Air Canada,(YYZ) Toronto,10:30 PM,Scheduled
# Dep,NZ 4736^,Air New Zealand,(YYZ) Toronto,10:30 PM,Scheduled
# Dep,UA 8436^,United Airlines,(YYZ) Toronto,10:30 PM,Scheduled
# Dep,AC 8081,Air Canada,(YYJ) Victoria,10:30 PM,Scheduled
# Dep,CA 7505^,Air China,(YYJ) Victoria,10:30 PM,Scheduled
# Dep,LX 4694^,SWISS,(YYJ) Victoria,10:30 PM,Scheduled
# Dep,NZ 4526^,Air New Zealand,(YYJ) Victoria,10:30 PM,Scheduled
# Dep,AC 8422,Air Canada,(YLW) Kelowna,10:30 PM,Scheduled
# Dep,CA 7511^,Air China,(YLW) Kelowna,10:30 PM,Scheduled
# Dep,LH 6614^,Lufthansa,(YLW) Kelowna,10:30 PM,Scheduled
# Dep,NZ 4574^,Air New Zealand,(YLW) Kelowna,10:30 PM,Scheduled
# Dep,AC 230,Air Canada,(YYC) Calgary,10:30 PM,Scheduled
# Dep,BR 3084^,EVA Air,(YYC) Calgary,10:30 PM,Scheduled
# Dep,CA 7483^,Air China,(YYC) Calgary,10:30 PM,Scheduled
# Dep,NZ 4512^,Air New Zealand,(YYC) Calgary,10:30 PM,Scheduled
# Dep,AC 8267,Air Canada,(YCD) Nanaimo,10:30 PM,Scheduled
# Dep,WS 724,WestJet,(YYZ) Toronto,10:35 PM,Scheduled
# Dep,CI 9312^,China Airlines,(YYZ) Toronto,10:35 PM,Scheduled
# Dep,DL 7108^,Delta Air Lines,(YYZ) Toronto,10:35 PM,Scheduled
# Dep,MU 8023^,China Eastern Airlines,(YYZ) Toronto,10:35 PM,Scheduled
# Dep,PR 1930^,Philippine Airlines,(YYZ) Toronto,10:35 PM,Scheduled
# Dep,DL 2450,Delta Air Lines,(ATL) Atlanta,10:40 PM,Scheduled
# Dep,AM 4674^,Aeromexico,(ATL) Atlanta,10:40 PM,Scheduled
# Dep,KL 7447^,KLM,(ATL) Atlanta,10:40 PM,Scheduled
# Dep,WS 6374^,WestJet,(ATL) Atlanta,10:40 PM,Scheduled
# Dep,CX 888,Cathay Pacific,(JFK) New York,10:55 PM,Scheduled
# Dep,UA 1279,United Airlines,(ORD) Chicago,10:59 PM,Scheduled
# Dep,AC 5104^,Air Canada,(ORD) Chicago,10:59 PM,Scheduled
# Dep,AC 128,Air Canada,(YYZ) Toronto,11:15 PM,Scheduled
# Dep,AV 6905^,AVIANCA,(YYZ) Toronto,11:15 PM,Scheduled
# Dep,CX 1524^,Cathay Pacific,(YYZ) Toronto,11:15 PM,Scheduled
# Dep,OS 8308^,Austrian,(YYZ) Toronto,11:15 PM,Scheduled
# Dep,AM 697,Aeromexico,(MEX) Mexico City,11:20 PM,Scheduled
# Dep,WS 6108^,WestJet,(MEX) Mexico City,11:20 PM,Scheduled
# Dep,AC 308,Air Canada,(YUL) Montreal,11:20 PM,Scheduled
# Dep,CA 7497^,Air China,(YUL) Montreal,11:20 PM,Scheduled
# Dep,CX 1510^,Cathay Pacific,(YUL) Montreal,11:20 PM,Scheduled
# Dep,NZ 4542^,Air New Zealand,(YUL) Montreal,11:20 PM,Scheduled
# Dep,AA 1519,American Airlines,(DFW) Dallas,11:25 PM,Scheduled
# Dep,BA 5680^,British Airways,(DFW) Dallas,11:25 PM,Scheduled
# Dep,UA 2150,United Airlines,(IAH) Houston,11:27 PM,Scheduled
# Dep,AC 5290^,Air Canada,(IAH) Houston,11:27 PM,Scheduled
# Dep,NZ 9975^,Air New Zealand,(IAH) Houston,11:27 PM,Scheduled
# Dep,PR 117,Philippine Airlines,(MNL) Manila,11:30 PM,Scheduled
# Dep,AC 35,Air Canada,(BNE) Brisbane,11:45 PM,Scheduled
# Dep,AC 33,Air Canada,(SYD) Sydney,11:50 PM,Scheduled
# Dep,NZ 4761^,Air New Zealand,(SYD) Sydney,11:50 PM,Scheduled
# Arr,Flight,Carrier,Origin,Arrival,Status
# Arr,AC 549,Air Canada,(EWR) Newark,9:02 PM,Scheduled
# Arr,WS 719,WestJet,(YYZ) Toronto,9:03 PM,Scheduled
# Arr,AF 3010^,Air France,(YYZ) Toronto,9:03 PM,Scheduled
# Arr,CI 9313^,China Airlines,(YYZ) Toronto,9:03 PM,Scheduled
# Arr,CX 7023^,Cathay Pacific,(YYZ) Toronto,9:03 PM,Scheduled
# Arr,DL 7107^,Delta Air Lines,(YYZ) Toronto,9:03 PM,Scheduled
# Arr,HU 8735^,Hainan Airlines,(YYZ) Toronto,9:03 PM,Scheduled
# Arr,MU 8018^,China Eastern Airlines,(YYZ) Toronto,9:03 PM,Scheduled
# Arr,PR 1931^,Philippine Airlines,(YYZ) Toronto,9:03 PM,Scheduled
# Arr,UA 829,United Airlines,(DEN) Denver,9:05 PM,Scheduled
# Arr,CM 1167^,Copa Airlines,(DEN) Denver,9:05 PM,Scheduled
# Arr,AC 229,Air Canada,(YYC) Calgary,9:06 PM,Scheduled
# Arr,BR 3083^,EVA Air,(YYC) Calgary,9:06 PM,Scheduled
# Arr,AC 8084,Air Canada,(SEA) Seattle,9:16 PM,Scheduled
# Arr,NZ 4816^,Air New Zealand,(SEA) Seattle,9:16 PM,Scheduled
# Arr,WS 199,WestJet,(YEG) Edmonton,9:18 PM,Scheduled
# Arr,AM 7353^,Aeromexico,(YEG) Edmonton,9:18 PM,Scheduled
# Arr,CI 9325^,China Airlines,(YEG) Edmonton,9:18 PM,Scheduled
# Arr,CX 7019^,Cathay Pacific,(YEG) Edmonton,9:18 PM,Scheduled
# Arr,MU 8064^,China Eastern Airlines,(YEG) Edmonton,9:18 PM,Scheduled
# Arr,PR 1901^,Philippine Airlines,(YEG) Edmonton,9:18 PM,Scheduled
# Arr,CX 888,Cathay Pacific,(HKG) Hong Kong,9:25 PM,Scheduled
# Arr,UA 1930,United Airlines,(IAH) Houston,9:25 PM,Scheduled
# Arr,AC 5592^,Air Canada,(IAH) Houston,9:25 PM,Scheduled
# Arr,AV 2186^,AVIANCA,(IAH) Houston,9:25 PM,Scheduled
# Arr,NZ 9973^,Air New Zealand,(IAH) Houston,9:25 PM,Scheduled
# Arr,UA 460,United Airlines,(SFO) San Francisco,9:26 PM,Scheduled
# Arr,CM 1119^,Copa Airlines,(SFO) San Francisco,9:26 PM,Scheduled
# Arr,NZ 9874^,Air New Zealand,(SFO) San Francisco,9:26 PM,Scheduled
# Arr,TS 875,Air Transat,(YYZ) Toronto,9:35 PM,Scheduled
# Arr,DL 2482,Delta Air Lines,(MSP) Minneapolis,9:35 PM,Scheduled
# Arr,AF 2384^,Air France,(MSP) Minneapolis,9:35 PM,Scheduled
# Arr,AM 4639^,Aeromexico,(MSP) Minneapolis,9:35 PM,Scheduled
# Arr,KE 3837^,Korean Air,(MSP) Minneapolis,9:35 PM,Scheduled
# Arr,KL 6784^,KLM,(MSP) Minneapolis,9:35 PM,Scheduled
# Arr,VS 1527^,Virgin Atlantic,(MSP) Minneapolis,9:35 PM,Scheduled
# Arr,WS 6387^,WestJet,(MSP) Minneapolis,9:35 PM,Scheduled
# Arr,AC 8180,Air Canada,(YXJ) Fort St. John,9:36 PM,Scheduled
# Arr,AC 8245,Air Canada,(YXT) Terrace,9:48 PM,Scheduled
# Arr,DL 5834,Delta Air Lines,(SLC) Salt Lake City,9:50 PM,Scheduled
# Arr,AF 2559^,Air France,(SLC) Salt Lake City,9:50 PM,Scheduled
# Arr,AM 5180^,Aeromexico,(SLC) Salt Lake City,9:50 PM,Scheduled
# Arr,KL 8136^,KLM,(SLC) Salt Lake City,9:50 PM,Scheduled
# Arr,VS 3603^,Virgin Atlantic,(SLC) Salt Lake City,9:50 PM,Scheduled
# Arr,WS 6409^,WestJet,(SLC) Salt Lake City,9:50 PM,Scheduled
# Arr,AC 8843,Air Canada,(SFO) San Francisco,9:52 PM,Scheduled
# Arr,LX 4663^,SWISS,(SFO) San Francisco,9:52 PM,Scheduled
# Arr,NZ 4618^,Air New Zealand,(SFO) San Francisco,9:52 PM,Scheduled
# Arr,AM 696,Aeromexico,(MEX) Mexico City,9:55 PM,Scheduled
# Arr,WS 6109^,WestJet,(MEX) Mexico City,9:55 PM,Scheduled
# Arr,DL 1805,Delta Air Lines,(ATL) Atlanta,9:57 PM,Scheduled
# Arr,AM 4621^,Aeromexico,(ATL) Atlanta,9:57 PM,Scheduled
# Arr,KL 7612^,KLM,(ATL) Atlanta,9:57 PM,Scheduled
# Arr,WS 6375^,WestJet,(ATL) Atlanta,9:57 PM,Scheduled
# Arr,AC 257,Air Canada,(YEG) Edmonton,9:58 PM,Scheduled
# Arr,BR 3085^,EVA Air,(YEG) Edmonton,9:58 PM,Scheduled
# Arr,WS 2057,WestJet,(CUN) Cancun,10:02 PM,Scheduled
# Arr,AC 33,Air Canada,(YYZ) Toronto,10:04 PM,Scheduled
# Arr,EI 8633^,Aer Lingus,(YYZ) Toronto,10:04 PM,Scheduled
# Arr,LH 6702^,Lufthansa,(YYZ) Toronto,10:04 PM,Scheduled
# Arr,OS 8342^,Austrian,(YYZ) Toronto,10:04 PM,Scheduled
# Arr,TK 8694^,Turkish Airlines,(YYZ) Toronto,10:04 PM,Scheduled
# Arr,UA 8437^,United Airlines,(YYZ) Toronto,10:04 PM,Scheduled
# Arr,TS 967,Air Transat,(YYZ) Toronto,10:05 PM,Scheduled
# Arr,UA 5903,United Airlines,(LAX) Los Angeles,10:15 PM,Scheduled
# Arr,NZ 9994^,Air New Zealand,(LAX) Los Angeles,10:15 PM,Scheduled
# Arr,UA 563,United Airlines,(ORD) Chicago,10:18 PM,Scheduled
# Arr,AC 5133^,Air Canada,(ORD) Chicago,10:18 PM,Scheduled
# Arr,EI 6445^,Aer Lingus,(ORD) Chicago,10:18 PM,Scheduled
# Arr,AS 2266,Alaska Airlines,(SEA) Seattle,10:20 PM,Scheduled
# Arr,FI 7675^,Icelandair,(SEA) Seattle,10:20 PM,Scheduled
# Arr,KE 6157^,Korean Air,(SEA) Seattle,10:20 PM,Scheduled
# Arr,WS 1699,WestJet,(LAX) Los Angeles,10:42 PM,Scheduled
# Arr,AF 3754^,Air France,(LAX) Los Angeles,10:42 PM,Scheduled
# Arr,AM 7390^,Aeromexico,(LAX) Los Angeles,10:42 PM,Scheduled
# Arr,CI 9320^,China Airlines,(LAX) Los Angeles,10:42 PM,Scheduled
# Arr,DL 7171^,Delta Air Lines,(LAX) Los Angeles,10:42 PM,Scheduled
# Arr,EK 4661^,Emirates,(LAX) Los Angeles,10:42 PM,Scheduled
# Arr,KE 6561^,Korean Air,(LAX) Los Angeles,10:42 PM,Scheduled
# Arr,QF 3397^,Qantas,(LAX) Los Angeles,10:42 PM,Scheduled
# Arr,AC 559,Air Canada,(LAX) Los Angeles,10:44 PM,Scheduled
# Arr,NZ 4604^,Air New Zealand,(LAX) Los Angeles,10:44 PM,Scheduled
# Arr,AA 6006,American Airlines,(LAX) Los Angeles,10:57 PM,Scheduled
# Arr,AS 6301^,Alaska Airlines,(LAX) Los Angeles,10:57 PM,Scheduled
# Arr,FJ 5205^,Fiji Airways,(LAX) Los Angeles,10:57 PM,Scheduled
# Arr,QF 3189^,Qantas,(LAX) Los Angeles,10:57 PM,Scheduled
# Arr,TN 1308^,Air Tahiti Nui,(LAX) Los Angeles,10:57 PM,Scheduled
# Arr,AC 255,Air Canada,(YEG) Edmonton,11:03 PM,Scheduled
# Arr,BR 3087^,EVA Air,(YEG) Edmonton,11:03 PM,Scheduled
# Arr,WS 143,WestJet,(YYC) Calgary,11:26 PM,Scheduled
# Arr,CI 9315^,China Airlines,(YYC) Calgary,11:26 PM,Scheduled
# Arr,CX 7029^,Cathay Pacific,(YYC) Calgary,11:26 PM,Scheduled
# Arr,MU 8060^,China Eastern Airlines,(YYC) Calgary,11:26 PM,Scheduled
# Arr,UA 1668,United Airlines,(SFO) San Francisco,11:47 PM,Scheduled
# Arr,AC 5111^,Air Canada,(SFO) San Francisco,11:47 PM,Scheduled
# Arr,NZ 9875^,Air New Zealand,(SFO) San Francisco,11:47 PM,Scheduled
# Arr,DL 2312,Delta Air Lines,(SEA) Seattle,11:50 PM,Scheduled
# Arr,AM 4709^,Aeromexico,(SEA) Seattle,11:50 PM,Scheduled
# Arr,WS 7140^,WestJet,(SEA) Seattle,11:50 PM,Scheduled
